# %%
from data.load_cifrar100 import *

train_loader, val_loader, test_loader = get_cifar100_dataloaders(
    batch_size=64,
    data_dir="./data",
    num_workers=4,
    val_split=0.1,
    img_size=32 , seed=77)

# %% [markdown]
# ---

# %%
from src.Model_A_OutGridNet import * 
from src.stage_config import *

from src.training.one_epoch_train import *
from src.training.train_full_model import *

# ---------------------------------------------------------
# MODELO 1: HÍBRIDO COMPLETO (Baseline)
# ---------------------------------------------------------
def configs_hybrid():
    return [
        StageCfg(dim=64,  depth=2, num_heads=2, grid_size=8, outlook_heads=2, drop_path=0.0),
        StageCfg(dim=128, depth=2, num_heads=4, grid_size=8, outlook_heads=4, drop_path=0.0),
        StageCfg(dim=256, depth=3, num_heads=8, grid_size=4, outlook_heads=8, drop_path=0.0),
        StageCfg(dim=384, depth=1, num_heads=6, grid_size=2, outlook_heads=6, drop_path=0.0),]

experiments = [
    {
        "name": "Hybrid_Full",
        "stages_fn": configs_hybrid,
        "dpr": 0.1,     
        "desc": "Baseline Completo"
    },]


def count_trainable_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def count_trainable_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

device = "cuda" if torch.cuda.is_available() else "cpu"

# Loop de entrenamiento
for exp in experiments:
    print(f"\n{'='*40}")
    print(f"Iniciando: {exp['name']} ({exp['desc']})")
    print(f"Drop Path Rate: {exp['dpr']}")
    print(f"{'='*40}")

    # Instanciar Modelo LIMPIO
    stages = exp["stages_fn"]()
    model = MaxOutNet(
        num_classes=100,
        stages=stages,
        stem_dim=64,
        dpr_max=exp["dpr"]).to(device)

    n_params = count_trainable_parameters(model)
    print(f"Trainable parameters: {n_params:,}")

    # Entrenar 100 Epocas
    history, _ = train_model(
        model=model,
        train_loader=train_loader,
        epochs=100,
        val_loader=val_loader,
        device=device,

        lr=5e-4,
        weight_decay=0.05,

        # Mixed Precision
        autocast_dtype="bf16" if device == "cuda" else "fp32",
        use_amp=(device == "cuda"),
        grad_clip_norm=1.0,

        warmup_ratio=0.05,
        min_lr=1e-6,

        label_smoothing=0.1,

        print_every=600,
        save_path=f"best_{exp['name']}.pt",
        last_path=f"last_{exp['name']}.pt",

        mix_prob=0.5,
        mixup_alpha=0.8,
        cutmix_alpha=1.0,

        num_classes=100,
        channels_last=True)

    print()
    print('Test del Modelo')
    free_all_cuda("model", "optimizer", "scaler", "scheduler", "batch", "loss", "outputs", "logits")
# Out:
# ========================================
# Iniciando: Hybrid_Full (Baseline Completo)
# Drop Path Rate: 0.1
# ========================================
# Trainable parameters: 14,599,198
# === Run config ===
# device=cuda | amp=True | autocast_dtype=bf16 | channels_last=True
# epochs=100 | steps/epoch=704 | total_steps=70400 | warmup_steps=3520
# batch_size=64 | input_shape=(64, 3, 32, 32) | num_classes=100
# opt=AdamW | lr=0.0005 | wd=0.05 | grad_clip_norm=1.0
# aug: mix_prob=0.5 | mixup_alpha=0.8 | cutmix_alpha=1.0 | label_smoothing=0.1
# early_stop=True | metric=top1 | patience=12 | min_delta=0.05
# ==================
#
# === Epoch 1/100 ===
# [train step 600/704] loss 4.2991 | top1 5.68% | top3 13.62% | top5 19.28% | 665.3 img/s | lr 8.52e-05 | gnorm 5.746 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 4.2481 | top1 6.40% | top3 15.08% | top5 21.13% | 663.2 img/s | lr 1.00e-04 | gnorm 5.707 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 4.2481 | top1 6.40% | top3 15.08% | top5 21.13% | lr 1.00e-04 | grad_norm 5.707 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 3.8252 | top1 10.28% | top3 24.02% | top5 32.86%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 10.280000)
# Epoch time: 1.19 min
#
# === Epoch 2/100 ===
# [train step 600/704] loss 3.8280 | top1 13.27% | top3 27.74% | top5 37.22% | 680.4 img/s | lr 1.85e-04 | gnorm 4.807 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 3.7963 | top1 13.90% | top3 28.54% | top5 38.08% | 677.5 img/s | lr 2.00e-04 | gnorm 4.758 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 3.7963 | top1 13.90% | top3 28.54% | top5 38.08% | lr 2.00e-04 | grad_norm 4.758 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 3.3775 | top1 18.56% | top3 36.16% | top5 47.26%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 18.560000)
# Epoch time: 1.16 min
#
# === Epoch 3/100 ===
# [train step 600/704] loss 3.4447 | top1 20.73% | top3 38.87% | top5 48.85% | 665.1 img/s | lr 2.85e-04 | gnorm 4.013 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 3.4164 | top1 21.24% | top3 39.58% | top5 49.60% | 667.8 img/s | lr 3.00e-04 | gnorm 3.977 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 3.4164 | top1 21.24% | top3 39.58% | top5 49.60% | lr 3.00e-04 | grad_norm 3.977 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 2.8561 | top1 27.96% | top3 49.32% | top5 60.92%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 27.960000)
# Epoch time: 1.18 min
#
# === Epoch 4/100 ===
# [train step 600/704] loss 3.1539 | top1 27.07% | top3 46.91% | top5 57.18% | 675.6 img/s | lr 3.85e-04 | gnorm 3.549 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 3.1351 | top1 27.57% | top3 47.47% | top5 57.68% | 674.4 img/s | lr 4.00e-04 | gnorm 3.528 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 3.1351 | top1 27.57% | top3 47.47% | top5 57.68% | lr 4.00e-04 | grad_norm 3.528 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 2.5988 | top1 34.00% | top3 54.54% | top5 65.88%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 34.000000)
# Epoch time: 1.17 min
#
# === Epoch 5/100 ===
# [train step 600/704] loss 2.9488 | top1 31.83% | top3 52.06% | top5 62.07% | 678.5 img/s | lr 4.85e-04 | gnorm 3.275 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.9546 | top1 31.84% | top3 52.13% | top5 62.06% | 674.6 img/s | lr 5.00e-04 | gnorm 3.251 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.9546 | top1 31.84% | top3 52.13% | top5 62.06% | lr 5.00e-04 | grad_norm 3.251 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 2.4410 | top1 36.98% | top3 59.44% | top5 69.00%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 36.980000)
# Epoch time: 1.17 min
#
# === Epoch 6/100 ===
# [train step 600/704] loss 2.7743 | top1 35.97% | top3 56.96% | top5 66.62% | 678.9 img/s | lr 5.00e-04 | gnorm 3.041 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.7814 | top1 36.04% | top3 56.85% | top5 66.42% | 679.1 img/s | lr 5.00e-04 | gnorm 3.026 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.7814 | top1 36.04% | top3 56.85% | top5 66.42% | lr 5.00e-04 | grad_norm 3.026 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 2.1914 | top1 42.84% | top3 65.46% | top5 75.08%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 42.840000)
# Epoch time: 1.16 min
#
# === Epoch 7/100 ===
# [train step 600/704] loss 2.5832 | top1 40.52% | top3 61.60% | top5 70.47% | 679.9 img/s | lr 5.00e-04 | gnorm 2.951 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.5940 | top1 40.38% | top3 61.48% | top5 70.43% | 679.4 img/s | lr 4.99e-04 | gnorm 2.944 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.5940 | top1 40.38% | top3 61.48% | top5 70.43% | lr 4.99e-04 | grad_norm 2.944 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 2.0320 | top1 45.94% | top3 69.10% | top5 77.64%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 45.940000)
# Epoch time: 1.16 min
#
# === Epoch 8/100 ===
# [train step 600/704] loss 2.4896 | top1 42.69% | top3 63.83% | top5 72.66% | 665.5 img/s | lr 4.99e-04 | gnorm 2.906 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.4752 | top1 43.06% | top3 64.17% | top5 72.96% | 667.7 img/s | lr 4.99e-04 | gnorm 2.907 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.4752 | top1 43.06% | top3 64.17% | top5 72.96% | lr 4.99e-04 | grad_norm 2.907 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.8623 | top1 50.44% | top3 72.16% | top5 80.66%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 50.440000)
# Epoch time: 1.18 min
#
# === Epoch 9/100 ===
# [train step 600/704] loss 2.3463 | top1 46.52% | top3 67.48% | top5 75.71% | 678.6 img/s | lr 4.98e-04 | gnorm 2.886 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.3541 | top1 46.46% | top3 67.35% | top5 75.59% | 677.6 img/s | lr 4.98e-04 | gnorm 2.884 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.3541 | top1 46.46% | top3 67.35% | top5 75.59% | lr 4.98e-04 | grad_norm 2.884 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.8152 | top1 51.38% | top3 73.30% | top5 81.74%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 51.380000)
# Epoch time: 1.16 min
#
# === Epoch 10/100 ===
# [train step 600/704] loss 2.2920 | top1 48.03% | top3 68.78% | top5 77.02% | 664.3 img/s | lr 4.97e-04 | gnorm 2.838 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.3051 | top1 47.95% | top3 68.76% | top5 76.99% | 663.8 img/s | lr 4.97e-04 | gnorm 2.832 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.3051 | top1 47.95% | top3 68.76% | top5 76.99% | lr 4.97e-04 | grad_norm 2.832 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.7402 | top1 54.00% | top3 74.90% | top5 82.34%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 54.000000)
# Epoch time: 1.18 min
#
# === Epoch 11/100 ===
# [train step 600/704] loss 2.2646 | top1 49.04% | top3 69.49% | top5 77.35% | 679.2 img/s | lr 4.95e-04 | gnorm 2.771 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.2522 | top1 49.16% | top3 69.56% | top5 77.44% | 678.6 img/s | lr 4.95e-04 | gnorm 2.779 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.2522 | top1 49.16% | top3 69.56% | top5 77.44% | lr 4.95e-04 | grad_norm 2.779 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.6635 | top1 54.86% | top3 76.58% | top5 84.44%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 54.860000)
# Epoch time: 1.16 min
#
# === Epoch 12/100 ===
# [train step 600/704] loss 2.1143 | top1 52.30% | top3 72.11% | top5 79.45% | 670.6 img/s | lr 4.94e-04 | gnorm 2.797 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.1156 | top1 52.08% | top3 72.17% | top5 79.52% | 670.2 img/s | lr 4.93e-04 | gnorm 2.807 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.1156 | top1 52.08% | top3 72.17% | top5 79.52% | lr 4.93e-04 | grad_norm 2.807 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.5652 | top1 57.62% | top3 78.32% | top5 85.16%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 57.620000)
# Epoch time: 1.17 min
#
# === Epoch 13/100 ===
# [train step 600/704] loss 2.0850 | top1 53.71% | top3 73.43% | top5 80.89% | 669.6 img/s | lr 4.92e-04 | gnorm 2.781 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.0716 | top1 53.90% | top3 73.58% | top5 80.92% | 670.3 img/s | lr 4.91e-04 | gnorm 2.800 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.0716 | top1 53.90% | top3 73.58% | top5 80.92% | lr 4.91e-04 | grad_norm 2.800 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.5286 | top1 57.50% | top3 79.36% | top5 86.04%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 14/100 ===
# [train step 600/704] loss 2.0285 | top1 55.04% | top3 74.96% | top5 81.97% | 682.4 img/s | lr 4.89e-04 | gnorm 2.770 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.0258 | top1 55.08% | top3 75.06% | top5 82.06% | 682.3 img/s | lr 4.89e-04 | gnorm 2.773 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.0258 | top1 55.08% | top3 75.06% | top5 82.06% | lr 4.89e-04 | grad_norm 2.773 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.4669 | top1 59.38% | top3 79.94% | top5 86.70%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 59.380000)
# Epoch time: 1.15 min
#
# === Epoch 15/100 ===
# [train step 600/704] loss 1.9992 | top1 55.81% | top3 75.29% | top5 82.19% | 672.2 img/s | lr 4.87e-04 | gnorm 2.795 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.0040 | top1 55.79% | top3 75.36% | top5 82.22% | 673.2 img/s | lr 4.86e-04 | gnorm 2.793 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.0040 | top1 55.79% | top3 75.36% | top5 82.22% | lr 4.86e-04 | grad_norm 2.793 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.4642 | top1 60.40% | top3 80.78% | top5 87.20%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 60.400000)
# Epoch time: 1.17 min
#
# === Epoch 16/100 ===
# [train step 600/704] loss 1.9578 | top1 56.78% | top3 75.76% | top5 82.40% | 674.2 img/s | lr 4.84e-04 | gnorm 2.729 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.9553 | top1 56.85% | top3 75.82% | top5 82.44% | 673.7 img/s | lr 4.84e-04 | gnorm 2.733 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.9553 | top1 56.85% | top3 75.82% | top5 82.44% | lr 4.84e-04 | grad_norm 2.733 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.4319 | top1 61.12% | top3 81.32% | top5 87.22%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 61.120000)
# Epoch time: 1.17 min
#
# === Epoch 17/100 ===
# [train step 600/704] loss 1.8611 | top1 59.18% | top3 77.61% | top5 83.96% | 673.0 img/s | lr 4.81e-04 | gnorm 2.765 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.8784 | top1 58.77% | top3 77.29% | top5 83.72% | 672.9 img/s | lr 4.81e-04 | gnorm 2.765 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.8784 | top1 58.77% | top3 77.29% | top5 83.72% | lr 4.81e-04 | grad_norm 2.765 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.3816 | top1 63.30% | top3 82.16% | top5 87.86%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 63.300000)
# Epoch time: 1.17 min
#
# === Epoch 18/100 ===
# [train step 600/704] loss 1.8107 | top1 59.91% | top3 78.43% | top5 84.70% | 672.5 img/s | lr 4.78e-04 | gnorm 2.794 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.8029 | top1 60.13% | top3 78.70% | top5 84.90% | 672.8 img/s | lr 4.77e-04 | gnorm 2.800 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.8029 | top1 60.13% | top3 78.70% | top5 84.90% | lr 4.77e-04 | grad_norm 2.800 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.3733 | top1 62.42% | top3 81.86% | top5 88.66%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 19/100 ===
# [train step 600/704] loss 1.8527 | top1 60.26% | top3 78.68% | top5 84.79% | 670.2 img/s | lr 4.74e-04 | gnorm 2.744 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.8656 | top1 60.02% | top3 78.47% | top5 84.65% | 670.0 img/s | lr 4.74e-04 | gnorm 2.748 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.8656 | top1 60.02% | top3 78.47% | top5 84.65% | lr 4.74e-04 | grad_norm 2.748 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.3348 | top1 64.58% | top3 83.22% | top5 88.86%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 64.580000)
# Epoch time: 1.18 min
#
# === Epoch 20/100 ===
# [train step 600/704] loss 1.7624 | top1 62.16% | top3 79.92% | top5 85.74% | 670.9 img/s | lr 4.71e-04 | gnorm 2.745 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.7687 | top1 61.76% | top3 79.65% | top5 85.55% | 671.7 img/s | lr 4.70e-04 | gnorm 2.755 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.7687 | top1 61.76% | top3 79.65% | top5 85.55% | lr 4.70e-04 | grad_norm 2.755 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.3270 | top1 64.70% | top3 82.90% | top5 88.24%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 64.700000)
# Epoch time: 1.17 min
#
# === Epoch 21/100 ===
# [train step 600/704] loss 1.7070 | top1 63.27% | top3 81.21% | top5 86.64% | 684.6 img/s | lr 4.66e-04 | gnorm 2.769 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.7143 | top1 63.10% | top3 81.01% | top5 86.52% | 681.4 img/s | lr 4.66e-04 | gnorm 2.768 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.7143 | top1 63.10% | top3 81.01% | top5 86.52% | lr 4.66e-04 | grad_norm 2.768 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.3858 | top1 63.62% | top3 82.78% | top5 88.20%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 22/100 ===
# [train step 600/704] loss 1.7560 | top1 62.74% | top3 80.54% | top5 86.17% | 676.6 img/s | lr 4.62e-04 | gnorm 2.736 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.7540 | top1 62.78% | top3 80.59% | top5 86.19% | 674.1 img/s | lr 4.62e-04 | gnorm 2.745 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.7540 | top1 62.78% | top3 80.59% | top5 86.19% | lr 4.62e-04 | grad_norm 2.745 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.3014 | top1 64.98% | top3 83.80% | top5 89.52%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 64.980000)
# Epoch time: 1.17 min
#
# === Epoch 23/100 ===
# [train step 600/704] loss 1.7035 | top1 63.47% | top3 80.85% | top5 86.45% | 679.4 img/s | lr 4.58e-04 | gnorm 2.725 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.7137 | top1 63.48% | top3 80.83% | top5 86.37% | 678.8 img/s | lr 4.57e-04 | gnorm 2.727 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.7137 | top1 63.48% | top3 80.83% | top5 86.37% | lr 4.57e-04 | grad_norm 2.727 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.2606 | top1 65.90% | top3 85.28% | top5 89.80%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 65.900000)
# Epoch time: 1.16 min
#
# === Epoch 24/100 ===
# [train step 600/704] loss 1.6593 | top1 65.22% | top3 82.49% | top5 87.61% | 673.7 img/s | lr 4.53e-04 | gnorm 2.760 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.6632 | top1 65.16% | top3 82.39% | top5 87.49% | 674.8 img/s | lr 4.52e-04 | gnorm 2.772 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.6632 | top1 65.16% | top3 82.39% | top5 87.49% | lr 4.52e-04 | grad_norm 2.772 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.2619 | top1 65.52% | top3 84.78% | top5 90.08%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 25/100 ===
# [train step 600/704] loss 1.6282 | top1 66.09% | top3 82.93% | top5 88.08% | 685.7 img/s | lr 4.48e-04 | gnorm 2.754 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.6515 | top1 65.61% | top3 82.53% | top5 87.72% | 684.7 img/s | lr 4.47e-04 | gnorm 2.749 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.6515 | top1 65.61% | top3 82.53% | top5 87.72% | lr 4.47e-04 | grad_norm 2.749 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.2036 | top1 67.82% | top3 85.44% | top5 90.78%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 67.820000)
# Epoch time: 1.15 min
#
# === Epoch 26/100 ===
# [train step 600/704] loss 1.5924 | top1 66.85% | top3 83.07% | top5 88.02% | 674.8 img/s | lr 4.43e-04 | gnorm 2.758 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5765 | top1 67.04% | top3 83.24% | top5 88.13% | 674.9 img/s | lr 4.42e-04 | gnorm 2.763 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5765 | top1 67.04% | top3 83.24% | top5 88.13% | lr 4.42e-04 | grad_norm 2.763 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.2045 | top1 67.00% | top3 85.08% | top5 90.76%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 27/100 ===
# [train step 600/704] loss 1.5040 | top1 68.11% | top3 84.28% | top5 88.78% | 677.0 img/s | lr 4.38e-04 | gnorm 2.808 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5078 | top1 68.11% | top3 84.26% | top5 88.79% | 676.5 img/s | lr 4.37e-04 | gnorm 2.814 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5078 | top1 68.11% | top3 84.26% | top5 88.79% | lr 4.37e-04 | grad_norm 2.814 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.2427 | top1 67.74% | top3 84.78% | top5 89.88%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 28/100 ===
# [train step 600/704] loss 1.5890 | top1 67.18% | top3 83.54% | top5 88.43% | 676.9 img/s | lr 4.32e-04 | gnorm 2.769 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5971 | top1 66.91% | top3 83.25% | top5 88.17% | 676.5 img/s | lr 4.31e-04 | gnorm 2.771 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5971 | top1 66.91% | top3 83.25% | top5 88.17% | lr 4.31e-04 | grad_norm 2.771 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1474 | top1 69.32% | top3 86.30% | top5 90.64%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 69.320000)
# Epoch time: 1.16 min
#
# === Epoch 29/100 ===
# [train step 600/704] loss 1.5408 | top1 68.71% | top3 84.63% | top5 89.16% | 677.8 img/s | lr 4.26e-04 | gnorm 2.784 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5379 | top1 68.67% | top3 84.64% | top5 89.22% | 676.1 img/s | lr 4.25e-04 | gnorm 2.805 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5379 | top1 68.67% | top3 84.64% | top5 89.22% | lr 4.25e-04 | grad_norm 2.805 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1661 | top1 68.16% | top3 85.76% | top5 90.64%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 30/100 ===
# [train step 600/704] loss 1.4358 | top1 70.59% | top3 85.87% | top5 90.15% | 672.6 img/s | lr 4.20e-04 | gnorm 2.804 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.4373 | top1 70.66% | top3 85.96% | top5 90.21% | 673.5 img/s | lr 4.19e-04 | gnorm 2.810 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.4373 | top1 70.66% | top3 85.96% | top5 90.21% | lr 4.19e-04 | grad_norm 2.810 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1519 | top1 67.60% | top3 85.88% | top5 90.80%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 31/100 ===
# [train step 600/704] loss 1.4495 | top1 70.34% | top3 85.51% | top5 89.76% | 671.1 img/s | lr 4.14e-04 | gnorm 2.783 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.4336 | top1 70.68% | top3 85.83% | top5 90.00% | 671.8 img/s | lr 4.13e-04 | gnorm 2.806 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.4336 | top1 70.68% | top3 85.83% | top5 90.00% | lr 4.13e-04 | grad_norm 2.806 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1347 | top1 68.42% | top3 86.22% | top5 91.04%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 32/100 ===
# [train step 600/704] loss 1.3935 | top1 72.19% | top3 86.92% | top5 90.91% | 679.0 img/s | lr 4.08e-04 | gnorm 2.793 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3788 | top1 72.45% | top3 87.16% | top5 91.13% | 676.9 img/s | lr 4.07e-04 | gnorm 2.823 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3788 | top1 72.45% | top3 87.16% | top5 91.13% | lr 4.07e-04 | grad_norm 2.823 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1823 | top1 68.16% | top3 85.22% | top5 90.60%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 33/100 ===
# [train step 600/704] loss 1.4472 | top1 70.96% | top3 85.43% | top5 89.74% | 671.7 img/s | lr 4.01e-04 | gnorm 2.792 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.4443 | top1 70.96% | top3 85.38% | top5 89.67% | 670.0 img/s | lr 4.00e-04 | gnorm 2.806 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.4443 | top1 70.96% | top3 85.38% | top5 89.67% | lr 4.00e-04 | grad_norm 2.806 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1674 | top1 68.88% | top3 86.14% | top5 91.02%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 34/100 ===
# [train step 600/704] loss 1.4097 | top1 72.23% | top3 86.33% | top5 90.32% | 676.2 img/s | lr 3.95e-04 | gnorm 2.791 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.4039 | top1 72.23% | top3 86.39% | top5 90.35% | 676.8 img/s | lr 3.94e-04 | gnorm 2.803 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.4039 | top1 72.23% | top3 86.39% | top5 90.35% | lr 3.94e-04 | grad_norm 2.803 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1467 | top1 68.52% | top3 85.56% | top5 90.70%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 35/100 ===
# [train step 600/704] loss 1.3506 | top1 73.24% | top3 87.04% | top5 90.84% | 680.5 img/s | lr 3.88e-04 | gnorm 2.804 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3391 | top1 73.53% | top3 87.36% | top5 91.10% | 680.3 img/s | lr 3.87e-04 | gnorm 2.818 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3391 | top1 73.53% | top3 87.36% | top5 91.10% | lr 3.87e-04 | grad_norm 2.818 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1252 | top1 69.48% | top3 86.56% | top5 91.42%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 69.480000)
# Epoch time: 1.16 min
#
# === Epoch 36/100 ===
# [train step 600/704] loss 1.3947 | top1 73.07% | top3 86.48% | top5 90.40% | 666.0 img/s | lr 3.81e-04 | gnorm 2.763 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3827 | top1 73.31% | top3 86.80% | top5 90.58% | 667.5 img/s | lr 3.80e-04 | gnorm 2.791 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3827 | top1 73.31% | top3 86.80% | top5 90.58% | lr 3.80e-04 | grad_norm 2.791 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1428 | top1 70.44% | top3 86.92% | top5 91.38%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 70.440000)
# Epoch time: 1.18 min
#
# === Epoch 37/100 ===
# [train step 600/704] loss 1.3828 | top1 72.88% | top3 86.61% | top5 90.39% | 676.9 img/s | lr 3.74e-04 | gnorm 2.788 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3636 | top1 72.99% | top3 86.70% | top5 90.50% | 677.0 img/s | lr 3.73e-04 | gnorm 2.806 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3636 | top1 72.99% | top3 86.70% | top5 90.50% | lr 3.73e-04 | grad_norm 2.806 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0949 | top1 69.58% | top3 86.98% | top5 91.32%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 38/100 ===
# [train step 600/704] loss 1.3255 | top1 74.80% | top3 87.62% | top5 91.14% | 678.4 img/s | lr 3.67e-04 | gnorm 2.763 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3213 | top1 74.72% | top3 87.65% | top5 91.19% | 675.0 img/s | lr 3.66e-04 | gnorm 2.781 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3213 | top1 74.72% | top3 87.65% | top5 91.19% | lr 3.66e-04 | grad_norm 2.781 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1165 | top1 69.88% | top3 86.26% | top5 91.14%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 39/100 ===
# [train step 600/704] loss 1.3316 | top1 74.56% | top3 87.56% | top5 91.02% | 676.3 img/s | lr 3.59e-04 | gnorm 2.771 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3555 | top1 74.07% | top3 87.10% | top5 90.72% | 676.6 img/s | lr 3.58e-04 | gnorm 2.775 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3555 | top1 74.07% | top3 87.10% | top5 90.72% | lr 3.58e-04 | grad_norm 2.775 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.1490 | top1 70.24% | top3 86.64% | top5 91.14%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 40/100 ===
# [train step 600/704] loss 1.3750 | top1 74.40% | top3 87.07% | top5 90.69% | 661.6 img/s | lr 3.52e-04 | gnorm 2.754 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3729 | top1 74.39% | top3 87.12% | top5 90.72% | 664.3 img/s | lr 3.51e-04 | gnorm 2.764 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3729 | top1 74.39% | top3 87.12% | top5 90.72% | lr 3.51e-04 | grad_norm 2.764 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0703 | top1 71.24% | top3 87.14% | top5 91.60%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 71.240000)
# Epoch time: 1.18 min
#
# === Epoch 41/100 ===
# [train step 600/704] loss 1.2107 | top1 77.03% | top3 89.04% | top5 92.20% | 677.2 img/s | lr 3.44e-04 | gnorm 2.819 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2474 | top1 76.09% | top3 88.32% | top5 91.62% | 675.7 img/s | lr 3.43e-04 | gnorm 2.832 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2474 | top1 76.09% | top3 88.32% | top5 91.62% | lr 3.43e-04 | grad_norm 2.832 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0912 | top1 71.14% | top3 87.22% | top5 91.52%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 42/100 ===
# [train step 600/704] loss 1.2456 | top1 76.55% | top3 88.55% | top5 91.82% | 677.7 img/s | lr 3.37e-04 | gnorm 2.802 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2342 | top1 76.90% | top3 88.79% | top5 92.04% | 678.0 img/s | lr 3.35e-04 | gnorm 2.822 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2342 | top1 76.90% | top3 88.79% | top5 92.04% | lr 3.35e-04 | grad_norm 2.822 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0740 | top1 70.64% | top3 87.00% | top5 91.24%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 43/100 ===
# [train step 600/704] loss 1.1361 | top1 79.28% | top3 90.50% | top5 93.36% | 669.8 img/s | lr 3.29e-04 | gnorm 2.777 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1678 | top1 78.56% | top3 89.98% | top5 92.94% | 670.4 img/s | lr 3.28e-04 | gnorm 2.787 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1678 | top1 78.56% | top3 89.98% | top5 92.94% | lr 3.28e-04 | grad_norm 2.787 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0960 | top1 71.02% | top3 86.68% | top5 91.58%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 44/100 ===
# [train step 600/704] loss 1.1963 | top1 77.78% | top3 89.10% | top5 92.16% | 676.4 img/s | lr 3.21e-04 | gnorm 2.778 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1893 | top1 77.96% | top3 89.35% | top5 92.36% | 676.2 img/s | lr 3.20e-04 | gnorm 2.801 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1893 | top1 77.96% | top3 89.35% | top5 92.36% | lr 3.20e-04 | grad_norm 2.801 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0718 | top1 71.00% | top3 87.22% | top5 92.00%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 45/100 ===
# [train step 600/704] loss 1.1580 | top1 79.08% | top3 90.33% | top5 93.01% | 675.6 img/s | lr 3.13e-04 | gnorm 2.774 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1871 | top1 78.58% | top3 89.89% | top5 92.66% | 674.6 img/s | lr 3.12e-04 | gnorm 2.777 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1871 | top1 78.58% | top3 89.89% | top5 92.66% | lr 3.12e-04 | grad_norm 2.777 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0864 | top1 71.62% | top3 87.46% | top5 92.00%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 71.620000)
# Epoch time: 1.17 min
#
# === Epoch 46/100 ===
# [train step 600/704] loss 1.2870 | top1 77.18% | top3 88.66% | top5 91.94% | 675.7 img/s | lr 3.05e-04 | gnorm 2.754 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2842 | top1 77.17% | top3 88.70% | top5 91.95% | 675.4 img/s | lr 3.04e-04 | gnorm 2.770 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2842 | top1 77.17% | top3 88.70% | top5 91.95% | lr 3.04e-04 | grad_norm 2.770 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0795 | top1 72.14% | top3 87.64% | top5 91.76%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 72.140000)
# Epoch time: 1.17 min
#
# === Epoch 47/100 ===
# [train step 600/704] loss 1.2490 | top1 77.64% | top3 88.89% | top5 91.92% | 670.8 img/s | lr 2.97e-04 | gnorm 2.740 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2310 | top1 78.12% | top3 89.18% | top5 92.13% | 672.0 img/s | lr 2.96e-04 | gnorm 2.762 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2310 | top1 78.12% | top3 89.18% | top5 92.13% | lr 2.96e-04 | grad_norm 2.762 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0464 | top1 72.10% | top3 87.86% | top5 92.18%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 48/100 ===
# [train step 600/704] loss 1.1842 | top1 78.14% | top3 89.02% | top5 91.98% | 685.0 img/s | lr 2.89e-04 | gnorm 2.754 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1846 | top1 78.23% | top3 89.15% | top5 92.08% | 684.1 img/s | lr 2.87e-04 | gnorm 2.764 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1846 | top1 78.23% | top3 89.15% | top5 92.08% | lr 2.87e-04 | grad_norm 2.764 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0912 | top1 70.64% | top3 87.54% | top5 91.88%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.14 min
#
# === Epoch 49/100 ===
# [train step 600/704] loss 1.2121 | top1 78.60% | top3 89.34% | top5 92.38% | 683.4 img/s | lr 2.81e-04 | gnorm 2.794 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2174 | top1 78.57% | top3 89.34% | top5 92.37% | 678.5 img/s | lr 2.79e-04 | gnorm 2.795 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2174 | top1 78.57% | top3 89.34% | top5 92.37% | lr 2.79e-04 | grad_norm 2.795 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0871 | top1 71.66% | top3 87.22% | top5 91.56%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 50/100 ===
# [train step 600/704] loss 1.1843 | top1 79.53% | top3 90.19% | top5 93.00% | 680.6 img/s | lr 2.72e-04 | gnorm 2.781 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1778 | top1 79.47% | top3 90.15% | top5 92.99% | 680.2 img/s | lr 2.71e-04 | gnorm 2.783 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1778 | top1 79.47% | top3 90.15% | top5 92.99% | lr 2.71e-04 | grad_norm 2.783 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0396 | top1 71.82% | top3 87.94% | top5 92.12%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 51/100 ===
# [train step 600/704] loss 1.1680 | top1 79.22% | top3 89.75% | top5 92.67% | 669.9 img/s | lr 2.64e-04 | gnorm 2.773 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1557 | top1 79.46% | top3 89.79% | top5 92.68% | 668.7 img/s | lr 2.63e-04 | gnorm 2.782 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1557 | top1 79.46% | top3 89.79% | top5 92.68% | lr 2.63e-04 | grad_norm 2.782 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0545 | top1 71.88% | top3 87.54% | top5 91.62%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 52/100 ===
# [train step 600/704] loss 1.1035 | top1 82.07% | top3 91.73% | top5 94.07% | 675.5 img/s | lr 2.56e-04 | gnorm 2.712 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1118 | top1 81.90% | top3 91.67% | top5 94.05% | 675.0 img/s | lr 2.55e-04 | gnorm 2.711 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1118 | top1 81.90% | top3 91.67% | top5 94.05% | lr 2.55e-04 | grad_norm 2.711 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0775 | top1 72.96% | top3 87.76% | top5 91.98%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 72.960000)
# Epoch time: 1.17 min
#
# === Epoch 53/100 ===
# [train step 600/704] loss 1.0680 | top1 81.15% | top3 90.89% | top5 93.47% | 679.5 img/s | lr 2.48e-04 | gnorm 2.714 | clip 99.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0737 | top1 81.32% | top3 91.01% | top5 93.60% | 676.8 img/s | lr 2.46e-04 | gnorm 2.723 | clip 99.9% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0737 | top1 81.32% | top3 91.01% | top5 93.60% | lr 2.46e-04 | grad_norm 2.723 | clip 99.9% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0352 | top1 72.22% | top3 87.70% | top5 91.90%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 54/100 ===
# [train step 600/704] loss 1.1083 | top1 81.64% | top3 91.04% | top5 93.59% | 682.8 img/s | lr 2.39e-04 | gnorm 2.753 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1079 | top1 81.66% | top3 91.06% | top5 93.56% | 681.9 img/s | lr 2.38e-04 | gnorm 2.765 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1079 | top1 81.66% | top3 91.06% | top5 93.56% | lr 2.38e-04 | grad_norm 2.765 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9955 | top1 73.26% | top3 88.06% | top5 92.28%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 73.260000)
# Epoch time: 1.16 min
#
# === Epoch 55/100 ===
# [train step 600/704] loss 1.0906 | top1 81.76% | top3 91.13% | top5 93.62% | 678.5 img/s | lr 2.31e-04 | gnorm 2.679 | clip 99.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0811 | top1 82.07% | top3 91.34% | top5 93.75% | 675.8 img/s | lr 2.30e-04 | gnorm 2.700 | clip 99.9% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0811 | top1 82.07% | top3 91.34% | top5 93.75% | lr 2.30e-04 | grad_norm 2.700 | clip 99.9% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0176 | top1 73.74% | top3 87.82% | top5 92.26%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 73.740000)
# Epoch time: 1.16 min
#
# === Epoch 56/100 ===
# [train step 600/704] loss 1.0494 | top1 82.56% | top3 91.36% | top5 93.90% | 678.5 img/s | lr 2.23e-04 | gnorm 2.718 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0726 | top1 82.11% | top3 91.18% | top5 93.74% | 678.8 img/s | lr 2.22e-04 | gnorm 2.733 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0726 | top1 82.11% | top3 91.18% | top5 93.74% | lr 2.22e-04 | grad_norm 2.733 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0420 | top1 73.10% | top3 88.10% | top5 91.98%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 57/100 ===
# [train step 600/704] loss 1.0049 | top1 83.66% | top3 92.31% | top5 94.53% | 681.2 img/s | lr 2.15e-04 | gnorm 2.653 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0151 | top1 83.31% | top3 92.08% | top5 94.38% | 679.7 img/s | lr 2.14e-04 | gnorm 2.679 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0151 | top1 83.31% | top3 92.08% | top5 94.38% | lr 2.14e-04 | grad_norm 2.679 | clip 99.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0256 | top1 73.78% | top3 88.60% | top5 92.42%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 58/100 ===
# [train step 600/704] loss 1.0641 | top1 82.52% | top3 91.21% | top5 93.60% | 678.9 img/s | lr 2.07e-04 | gnorm 2.675 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0469 | top1 82.62% | top3 91.25% | top5 93.64% | 678.7 img/s | lr 2.05e-04 | gnorm 2.706 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0469 | top1 82.62% | top3 91.25% | top5 93.64% | lr 2.05e-04 | grad_norm 2.706 | clip 99.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9825 | top1 73.54% | top3 88.38% | top5 92.38%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 59/100 ===
# [train step 600/704] loss 1.0101 | top1 84.13% | top3 92.12% | top5 94.30% | 676.5 img/s | lr 1.98e-04 | gnorm 2.635 | clip 99.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0323 | top1 83.91% | top3 92.02% | top5 94.24% | 674.4 img/s | lr 1.97e-04 | gnorm 2.662 | clip 99.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0323 | top1 83.91% | top3 92.02% | top5 94.24% | lr 1.97e-04 | grad_norm 2.662 | clip 99.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9708 | top1 73.98% | top3 88.86% | top5 92.32%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 73.980000)
# Epoch time: 1.17 min
#
# === Epoch 60/100 ===
# [train step 600/704] loss 1.0512 | top1 83.42% | top3 91.75% | top5 94.17% | 683.4 img/s | lr 1.90e-04 | gnorm 2.654 | clip 99.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0540 | top1 83.16% | top3 91.59% | top5 94.02% | 682.4 img/s | lr 1.89e-04 | gnorm 2.697 | clip 99.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0540 | top1 83.16% | top3 91.59% | top5 94.02% | lr 1.89e-04 | grad_norm 2.697 | clip 99.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9923 | top1 73.98% | top3 88.44% | top5 92.42%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 61/100 ===
# [train step 600/704] loss 1.0846 | top1 82.07% | top3 90.83% | top5 93.49% | 673.3 img/s | lr 1.82e-04 | gnorm 2.648 | clip 98.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0915 | top1 81.95% | top3 90.81% | top5 93.46% | 671.7 img/s | lr 1.81e-04 | gnorm 2.678 | clip 98.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0915 | top1 81.95% | top3 90.81% | top5 93.46% | lr 1.81e-04 | grad_norm 2.678 | clip 98.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0233 | top1 73.54% | top3 88.16% | top5 91.64%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 62/100 ===
# [train step 600/704] loss 1.0705 | top1 83.01% | top3 91.55% | top5 93.97% | 682.9 img/s | lr 1.75e-04 | gnorm 2.652 | clip 99.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0863 | top1 82.72% | top3 91.41% | top5 93.85% | 682.8 img/s | lr 1.73e-04 | gnorm 2.655 | clip 99.3% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0863 | top1 82.72% | top3 91.41% | top5 93.85% | lr 1.73e-04 | grad_norm 2.655 | clip 99.3% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9930 | top1 73.90% | top3 88.86% | top5 92.72%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 63/100 ===
# [train step 600/704] loss 1.0592 | top1 83.97% | top3 92.14% | top5 94.33% | 675.3 img/s | lr 1.67e-04 | gnorm 2.613 | clip 99.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0563 | top1 84.02% | top3 92.20% | top5 94.37% | 675.1 img/s | lr 1.66e-04 | gnorm 2.640 | clip 99.3% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0563 | top1 84.02% | top3 92.20% | top5 94.37% | lr 1.66e-04 | grad_norm 2.640 | clip 99.3% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9767 | top1 75.24% | top3 89.14% | top5 92.64%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 75.240000)
# Epoch time: 1.17 min
#
# === Epoch 64/100 ===
# [train step 600/704] loss 1.1220 | top1 81.54% | top3 90.19% | top5 92.68% | 679.2 img/s | lr 1.59e-04 | gnorm 2.650 | clip 99.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1103 | top1 81.78% | top3 90.44% | top5 92.92% | 677.4 img/s | lr 1.58e-04 | gnorm 2.662 | clip 98.9% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1103 | top1 81.78% | top3 90.44% | top5 92.92% | lr 1.58e-04 | grad_norm 2.662 | clip 98.9% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 1.0120 | top1 74.30% | top3 89.06% | top5 92.78%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 65/100 ===
# [train step 600/704] loss 1.0344 | top1 83.73% | top3 91.62% | top5 94.00% | 683.5 img/s | lr 1.51e-04 | gnorm 2.627 | clip 98.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0281 | top1 83.78% | top3 91.70% | top5 94.04% | 682.4 img/s | lr 1.50e-04 | gnorm 2.653 | clip 98.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0281 | top1 83.78% | top3 91.70% | top5 94.04% | lr 1.50e-04 | grad_norm 2.653 | clip 98.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9599 | top1 74.20% | top3 89.38% | top5 92.76%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 66/100 ===
# ...
#
# === Epoch 76/100 ===
# [train step 600/704] loss 0.9075 | top1 86.41% | top3 93.09% | top5 95.03% | 679.7 img/s | lr 7.64e-05 | gnorm 2.450 | clip 95.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9018 | top1 86.61% | top3 93.23% | top5 95.13% | 680.3 img/s | lr 7.55e-05 | gnorm 2.444 | clip 94.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9018 | top1 86.61% | top3 93.23% | top5 95.13% | lr 7.55e-05 | grad_norm 2.444 | clip 94.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9088 | top1 76.40% | top3 89.44% | top5 92.88%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 76.400000)
# Epoch time: 1.16 min
#
# === Epoch 77/100 ===
# [train step 600/704] loss 0.9054 | top1 86.61% | top3 93.25% | top5 95.18% | 674.0 img/s | lr 7.06e-05 | gnorm 2.371 | clip 90.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9045 | top1 86.86% | top3 93.40% | top5 95.30% | 674.5 img/s | lr 6.98e-05 | gnorm 2.379 | clip 90.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9045 | top1 86.86% | top3 93.40% | top5 95.30% | lr 6.98e-05 | grad_norm 2.379 | clip 90.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9195 | top1 75.90% | top3 89.90% | top5 93.12%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 78/100 ===
# [train step 600/704] loss 0.9898 | top1 86.43% | top3 93.23% | top5 95.18% | 678.3 img/s | lr 6.50e-05 | gnorm 2.513 | clip 92.2% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9794 | top1 86.60% | top3 93.28% | top5 95.18% | 676.8 img/s | lr 6.42e-05 | gnorm 2.483 | clip 91.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9794 | top1 86.60% | top3 93.28% | top5 95.18% | lr 6.42e-05 | grad_norm 2.483 | clip 91.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9213 | top1 76.32% | top3 89.84% | top5 93.44%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 79/100 ===
# [train step 600/704] loss 0.8750 | top1 87.47% | top3 93.55% | top5 95.39% | 665.5 img/s | lr 5.96e-05 | gnorm 2.345 | clip 89.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8580 | top1 87.56% | top3 93.55% | top5 95.41% | 667.4 img/s | lr 5.88e-05 | gnorm 2.352 | clip 89.3% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8580 | top1 87.56% | top3 93.55% | top5 95.41% | lr 5.88e-05 | grad_norm 2.352 | clip 89.3% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9071 | top1 76.30% | top3 90.12% | top5 93.52%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 80/100 ===
# [train step 600/704] loss 0.9599 | top1 85.88% | top3 92.61% | top5 94.75% | 674.0 img/s | lr 5.44e-05 | gnorm 2.403 | clip 87.2% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9757 | top1 85.66% | top3 92.53% | top5 94.69% | 674.2 img/s | lr 5.36e-05 | gnorm 2.433 | clip 88.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9757 | top1 85.66% | top3 92.53% | top5 94.69% | lr 5.36e-05 | grad_norm 2.433 | clip 88.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9020 | top1 76.68% | top3 89.52% | top5 92.96%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 76.680000)
# Epoch time: 1.17 min
#
# === Epoch 81/100 ===
# [train step 600/704] loss 1.0027 | top1 86.10% | top3 93.04% | top5 95.01% | 677.3 img/s | lr 4.94e-05 | gnorm 2.391 | clip 88.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9983 | top1 86.24% | top3 93.11% | top5 95.10% | 676.9 img/s | lr 4.87e-05 | gnorm 2.397 | clip 88.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9983 | top1 86.24% | top3 93.11% | top5 95.10% | lr 4.87e-05 | grad_norm 2.397 | clip 88.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9118 | top1 76.38% | top3 89.56% | top5 93.40%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 82/100 ===
# [train step 600/704] loss 0.9190 | top1 86.83% | top3 93.14% | top5 95.07% | 668.1 img/s | lr 4.46e-05 | gnorm 2.405 | clip 89.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9026 | top1 87.07% | top3 93.26% | top5 95.17% | 667.6 img/s | lr 4.39e-05 | gnorm 2.410 | clip 88.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9026 | top1 87.07% | top3 93.26% | top5 95.17% | lr 4.39e-05 | grad_norm 2.410 | clip 88.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9206 | top1 76.70% | top3 89.84% | top5 93.48%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 83/100 ===
# [train step 600/704] loss 0.8632 | top1 88.53% | top3 94.41% | top5 96.03% | 672.4 img/s | lr 4.01e-05 | gnorm 2.255 | clip 86.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8887 | top1 88.08% | top3 94.13% | top5 95.83% | 672.9 img/s | lr 3.94e-05 | gnorm 2.286 | clip 85.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8887 | top1 88.08% | top3 94.13% | top5 95.83% | lr 3.94e-05 | grad_norm 2.286 | clip 85.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.8967 | top1 76.46% | top3 90.00% | top5 93.76%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 84/100 ===
# [train step 600/704] loss 0.9922 | top1 85.43% | top3 92.52% | top5 94.64% | 679.3 img/s | lr 3.57e-05 | gnorm 2.375 | clip 86.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0069 | top1 85.28% | top3 92.43% | top5 94.56% | 678.9 img/s | lr 3.51e-05 | gnorm 2.389 | clip 86.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0069 | top1 85.28% | top3 92.43% | top5 94.56% | lr 3.51e-05 | grad_norm 2.389 | clip 86.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9061 | top1 76.66% | top3 89.64% | top5 93.16%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 85/100 ===
# [train step 600/704] loss 0.9392 | top1 87.49% | top3 93.79% | top5 95.66% | 672.3 img/s | lr 3.17e-05 | gnorm 2.300 | clip 84.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9476 | top1 87.20% | top3 93.58% | top5 95.50% | 671.2 img/s | lr 3.11e-05 | gnorm 2.312 | clip 84.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9476 | top1 87.20% | top3 93.58% | top5 95.50% | lr 3.11e-05 | grad_norm 2.312 | clip 84.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.8790 | top1 77.42% | top3 89.94% | top5 93.52%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Best saved to best_Hybrid_Full.pt (val top1 = 77.420000)
# Epoch time: 1.17 min
#
# === Epoch 86/100 ===
# [train step 600/704] loss 0.9637 | top1 86.61% | top3 93.28% | top5 95.23% | 668.6 img/s | lr 2.78e-05 | gnorm 2.350 | clip 83.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9688 | top1 86.59% | top3 93.25% | top5 95.19% | 670.0 img/s | lr 2.73e-05 | gnorm 2.397 | clip 84.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9688 | top1 86.59% | top3 93.25% | top5 95.19% | lr 2.73e-05 | grad_norm 2.397 | clip 84.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9034 | top1 76.42% | top3 89.96% | top5 93.38%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 87/100 ===
# [train step 600/704] loss 0.9493 | top1 87.09% | top3 93.48% | top5 95.37% | 672.3 img/s | lr 2.42e-05 | gnorm 2.330 | clip 84.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9689 | top1 86.68% | top3 93.22% | top5 95.18% | 671.8 img/s | lr 2.37e-05 | gnorm 2.351 | clip 85.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9689 | top1 86.68% | top3 93.22% | top5 95.18% | lr 2.37e-05 | grad_norm 2.351 | clip 85.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9288 | top1 76.38% | top3 89.74% | top5 93.26%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 88/100 ===
# [train step 600/704] loss 0.9003 | top1 88.09% | top3 94.05% | top5 95.74% | 677.2 img/s | lr 2.09e-05 | gnorm 2.290 | clip 83.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8809 | top1 88.43% | top3 94.20% | top5 95.87% | 676.7 img/s | lr 2.04e-05 | gnorm 2.282 | clip 83.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8809 | top1 88.43% | top3 94.20% | top5 95.87% | lr 2.04e-05 | grad_norm 2.282 | clip 83.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9021 | top1 76.86% | top3 90.02% | top5 93.46%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 89/100 ===
# [train step 600/704] loss 0.9064 | top1 87.84% | top3 94.01% | top5 95.77% | 667.0 img/s | lr 1.78e-05 | gnorm 2.336 | clip 85.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9383 | top1 87.35% | top3 93.69% | top5 95.55% | 664.7 img/s | lr 1.73e-05 | gnorm 2.338 | clip 84.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9383 | top1 87.35% | top3 93.69% | top5 95.55% | lr 1.73e-05 | grad_norm 2.338 | clip 84.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9665 | top1 76.10% | top3 90.02% | top5 93.14%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.18 min
#
# === Epoch 90/100 ===
# [train step 600/704] loss 0.9649 | top1 86.60% | top3 93.31% | top5 95.34% | 668.2 img/s | lr 1.49e-05 | gnorm 2.326 | clip 81.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9410 | top1 87.08% | top3 93.59% | top5 95.52% | 668.0 img/s | lr 1.45e-05 | gnorm 2.312 | clip 82.2% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9410 | top1 87.08% | top3 93.59% | top5 95.52% | lr 1.45e-05 | grad_norm 2.312 | clip 82.2% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9036 | top1 76.52% | top3 89.90% | top5 93.46%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 91/100 ===
# [train step 600/704] loss 0.9066 | top1 87.31% | top3 93.62% | top5 95.46% | 671.7 img/s | lr 1.23e-05 | gnorm 2.283 | clip 81.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8885 | top1 87.59% | top3 93.76% | top5 95.55% | 672.8 img/s | lr 1.20e-05 | gnorm 2.274 | clip 81.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8885 | top1 87.59% | top3 93.76% | top5 95.55% | lr 1.20e-05 | grad_norm 2.274 | clip 81.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.8888 | top1 76.96% | top3 90.04% | top5 93.48%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 92/100 ===
# [train step 600/704] loss 0.9646 | top1 85.90% | top3 92.56% | top5 94.57% | 671.7 img/s | lr 1.00e-05 | gnorm 2.257 | clip 80.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9667 | top1 85.80% | top3 92.57% | top5 94.59% | 672.4 img/s | lr 9.68e-06 | gnorm 2.290 | clip 81.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9667 | top1 85.80% | top3 92.57% | top5 94.59% | lr 9.68e-06 | grad_norm 2.290 | clip 81.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9139 | top1 77.08% | top3 90.10% | top5 93.48%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.16 min
#
# === Epoch 93/100 ===
# [train step 600/704] loss 0.8725 | top1 88.41% | top3 94.37% | top5 96.13% | 669.2 img/s | lr 7.94e-06 | gnorm 2.225 | clip 80.2% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8896 | top1 88.06% | top3 94.13% | top5 95.93% | 669.3 img/s | lr 7.66e-06 | gnorm 2.244 | clip 80.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8896 | top1 88.06% | top3 94.13% | top5 95.93% | lr 7.66e-06 | grad_norm 2.244 | clip 80.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.8969 | top1 76.88% | top3 90.16% | top5 93.26%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 94/100 ===
# [train step 600/704] loss 0.8928 | top1 88.06% | top3 94.08% | top5 95.82% | 653.1 img/s | lr 6.14e-06 | gnorm 2.237 | clip 81.2% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8908 | top1 88.18% | top3 94.16% | top5 95.87% | 654.0 img/s | lr 5.90e-06 | gnorm 2.240 | clip 80.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8908 | top1 88.18% | top3 94.16% | top5 95.87% | lr 5.90e-06 | grad_norm 2.240 | clip 80.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.8988 | top1 76.60% | top3 89.98% | top5 93.38%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.20 min
#
# === Epoch 95/100 ===
# [train step 600/704] loss 0.9058 | top1 87.65% | top3 93.72% | top5 95.48% | 681.8 img/s | lr 4.61e-06 | gnorm 2.251 | clip 81.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8943 | top1 87.68% | top3 93.78% | top5 95.53% | 680.2 img/s | lr 4.40e-06 | gnorm 2.246 | clip 81.8% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8943 | top1 87.68% | top3 93.78% | top5 95.53% | lr 4.40e-06 | grad_norm 2.246 | clip 81.8% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9011 | top1 77.12% | top3 90.12% | top5 93.24%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.15 min
#
# === Epoch 96/100 ===
# [train step 600/704] loss 0.9055 | top1 87.43% | top3 93.62% | top5 95.44% | 669.0 img/s | lr 3.34e-06 | gnorm 2.210 | clip 80.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9116 | top1 87.31% | top3 93.57% | top5 95.41% | 667.0 img/s | lr 3.18e-06 | gnorm 2.234 | clip 81.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9116 | top1 87.31% | top3 93.57% | top5 95.41% | lr 3.18e-06 | grad_norm 2.234 | clip 81.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.8985 | top1 77.20% | top3 90.14% | top5 93.80%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Epoch time: 1.17 min
#
# === Epoch 97/100 ===
# [train step 600/704] loss 0.9096 | top1 87.39% | top3 93.57% | top5 95.36% | 678.8 img/s | lr 2.35e-06 | gnorm 2.229 | clip 81.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9225 | top1 87.24% | top3 93.52% | top5 95.34% | 676.4 img/s | lr 2.23e-06 | gnorm 2.236 | clip 81.2% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9225 | top1 87.24% | top3 93.52% | top5 95.34% | lr 2.23e-06 | grad_norm 2.236 | clip 81.2% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 3.21 GiB | reserved 3.73 GiB
# [Val]   loss 0.9522 | top1 76.72% | top3 89.82% | top5 93.18%
# [Val]   mem_peak alloc 1.31 GiB | reserved 3.73 GiB
# Early-stop: no improvement on val_top1 for 12 epochs.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3136103491.py in <cell line: 0>()
#      54         channels_last=True)
#      55
# ---> 56     print(f"Finalizado {exp['name']}. Best Val Top1: {max([h['val_acc_top1'] for h in history]):.2f}%")
#      57     print()
#      58     print()
#
# TypeError: string indices must be integers, not 'str'

# %%
evaluate_one_epoch(model=model,dataloader=test_loader)
# Out:
# (0.828276930809021, {'top1': 79.85, 'top3': 91.74, 'top5': 94.9})

# %% [markdown]
# ---
