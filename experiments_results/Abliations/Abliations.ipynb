# %%
from data.load_cifrar100 import *


train_loader, val_loader, test_loader = get_cifar100_dataloaders(
    batch_size=64,
    data_dir="./data",
    num_workers=4,
    val_split=0.1,
    img_size=32 , seed=77)

# %% [markdown]
# ---

# %%
from src.Model_A_OutGridNet import * 
from src.stage_config import *

from src.training.one_epoch_train import *
from src.training.train_full_model import *

# ---------------------------------------------------------
# MODELO 2: NO OUTLOOKER (Solo Grid + MBConv)
# ---------------------------------------------------------
def configs_no_outlooker():
    return [
        StageCfg(dim=64,  depth=2, num_heads=2, grid_size=8, outlook_heads=0, drop_path=0.0),
        StageCfg(dim=128, depth=2, num_heads=4, grid_size=8, outlook_heads=0, drop_path=0.0),
        StageCfg(dim=256, depth=3, num_heads=8, grid_size=4, outlook_heads=0, drop_path=0.0),
        StageCfg(dim=384, depth=1, num_heads=6, grid_size=2, outlook_heads=0, drop_path=0.0),]

# ---------------------------------------------------------
# MODELO 3: NO GRID (Solo Outlooker + MBConv)
# ---------------------------------------------------------
def configs_no_grid():
    return [
        StageCfg(dim=64,  depth=2, num_heads=0, grid_size=8, outlook_heads=2, drop_path=0.0),
        StageCfg(dim=128, depth=2, num_heads=0, grid_size=8, outlook_heads=4, drop_path=0.0),
        StageCfg(dim=256, depth=3, num_heads=0, grid_size=4, outlook_heads=8, drop_path=0.0),
        StageCfg(dim=384, depth=1, num_heads=0, grid_size=2, outlook_heads=6, drop_path=0.0),]

# ---------------------------------------------------------
# MODELO 4: PLAIN (Solo MBConv)
# ---------------------------------------------------------
def configs_plain():
    return [
        StageCfg(dim=64,  depth=2, num_heads=0, grid_size=8, outlook_heads=0, drop_path=0.0),
        StageCfg(dim=128, depth=2, num_heads=0, grid_size=8, outlook_heads=0, drop_path=0.0),
        StageCfg(dim=256, depth=3, num_heads=0, grid_size=4, outlook_heads=0, drop_path=0.0),
        StageCfg(dim=384, depth=1, num_heads=0, grid_size=2, outlook_heads=0, drop_path=0.0),]

experiments = [
    {
        "name": "No_Outlooker",
        "stages_fn": configs_no_outlooker,
        "dpr": 0.05, 
        "desc": "Ablation: Sin Outlooker"
    },
    {
        "name": "No_Grid",
        "stages_fn": configs_no_grid,
        "dpr": 0.05,     
        "desc": "Ablation: Sin Grid"
    },
    {
        "name": "Plain_MBConv",
        "stages_fn": configs_plain,
        "dpr": 0.0,    
        "desc": "Baseline: Solo Convolucional"
    }]

# %%
def count_trainable_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

device = "cuda" if torch.cuda.is_available() else "cpu"

# Loop de entrenamiento
for exp in experiments:
    print(f"\n{'='*40}")
    print(f"Iniciando: {exp['name']} ({exp['desc']})")
    print(f"Drop Path Rate: {exp['dpr']}")
    print(f"{'='*40}")

    # Instanciar Modelo LIMPIO
    stages = exp["stages_fn"]()
    model = MaxOutNet(
        num_classes=100,
        stages=stages,
        stem_dim=64,
        dpr_max=exp["dpr"]).to(device)

    n_params = count_trainable_parameters(model)
    print(f"Trainable parameters: {n_params:,}")

    # Entrenar 100 Epocas
    history, _ = train_model(
        model=model,
        train_loader=train_loader,
        epochs=100,
        val_loader=val_loader,
        device=device,

        lr=5e-4,
        weight_decay=0.05,

        # Mixed Precision
        autocast_dtype="bf16" if device == "cuda" else "fp32",
        use_amp=(device == "cuda"),
        grad_clip_norm=1.0,

        warmup_ratio=0.05,
        min_lr=1e-6,

        label_smoothing=0.1,

        print_every=600,
        save_path=f"best_{exp['name']}.pt",
        last_path=f"last_{exp['name']}.pt",

        mix_prob=0.5,
        mixup_alpha=0.8,
        cutmix_alpha=1.0,

        num_classes=100,
        channels_last=True)

    print()
    print('Test del Modelo')
    evaluate_one_epoch(model=model,dataloader=test_loader)
    free_all_cuda("model", "optimizer", "scaler", "scheduler", "batch", "loss", "outputs", "logits")
# Out:
# ========================================
# Iniciando: No_Outlooker (Ablation: Sin Outlooker)
# Drop Path Rate: 0.05
# ========================================
# Trainable parameters: 12,187,300
# === Run config ===
# device=cuda | amp=True | autocast_dtype=bf16 | channels_last=True
# epochs=100 | steps/epoch=704 | total_steps=70400 | warmup_steps=3520
# batch_size=64 | input_shape=(64, 3, 32, 32) | num_classes=100
# opt=AdamW | lr=0.0005 | wd=0.05 | grad_clip_norm=1.0
# aug: mix_prob=0.5 | mixup_alpha=0.8 | cutmix_alpha=1.0 | label_smoothing=0.1
# early_stop=True | metric=top1 | patience=12 | min_delta=0.05
# ==================
#
# === Epoch 1/100 ===
# [train step 600/704] loss 4.3293 | top1 5.42% | top3 12.91% | top5 18.62% | 1037.2 img/s | lr 8.52e-05 | gnorm 5.446 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 4.2894 | top1 5.86% | top3 13.96% | top5 20.07% | 1040.2 img/s | lr 1.00e-04 | gnorm 5.391 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 4.2894 | top1 5.86% | top3 13.96% | top5 20.07% | lr 1.00e-04 | grad_norm 5.391 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 3.8399 | top1 11.74% | top3 24.72% | top5 33.44%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 11.740000)
# Epoch time: 0.75 min
#
# === Epoch 2/100 ===
# [train step 600/704] loss 3.7950 | top1 14.10% | top3 28.59% | top5 38.01% | 1046.9 img/s | lr 1.85e-04 | gnorm 4.770 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 3.7614 | top1 14.62% | top3 29.43% | top5 38.89% | 1046.3 img/s | lr 2.00e-04 | gnorm 4.741 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 3.7614 | top1 14.62% | top3 29.43% | top5 38.89% | lr 2.00e-04 | grad_norm 4.741 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 3.2352 | top1 21.22% | top3 39.08% | top5 50.04%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 21.220000)
# Epoch time: 0.75 min
#
# === Epoch 3/100 ===
# [train step 600/704] loss 3.3945 | top1 21.92% | top3 40.29% | top5 50.12% | 1058.9 img/s | lr 2.85e-04 | gnorm 4.117 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 3.3709 | top1 22.39% | top3 40.95% | top5 50.87% | 1059.8 img/s | lr 3.00e-04 | gnorm 4.084 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 3.3709 | top1 22.39% | top3 40.95% | top5 50.87% | lr 3.00e-04 | grad_norm 4.084 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 2.8645 | top1 27.74% | top3 48.72% | top5 59.82%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 27.740000)
# Epoch time: 0.75 min
#
# === Epoch 4/100 ===
# [train step 600/704] loss 3.0846 | top1 27.93% | top3 48.24% | top5 58.39% | 1054.0 img/s | lr 3.85e-04 | gnorm 3.617 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 3.0726 | top1 28.37% | top3 48.71% | top5 58.78% | 1055.2 img/s | lr 4.00e-04 | gnorm 3.581 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 3.0726 | top1 28.37% | top3 48.71% | top5 58.78% | lr 4.00e-04 | grad_norm 3.581 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 2.5723 | top1 34.40% | top3 55.72% | top5 66.60%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 34.400000)
# Epoch time: 0.75 min
#
# === Epoch 5/100 ===
# [train step 600/704] loss 2.8864 | top1 32.61% | top3 53.41% | top5 63.39% | 1061.9 img/s | lr 4.85e-04 | gnorm 3.210 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.8806 | top1 32.93% | top3 53.63% | top5 63.56% | 1061.0 img/s | lr 5.00e-04 | gnorm 3.193 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.8806 | top1 32.93% | top3 53.63% | top5 63.56% | lr 5.00e-04 | grad_norm 3.193 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 2.3306 | top1 39.46% | top3 62.46% | top5 72.48%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 39.460000)
# Epoch time: 0.74 min
#
# === Epoch 6/100 ===
# [train step 600/704] loss 2.6644 | top1 37.67% | top3 59.13% | top5 68.58% | 1057.8 img/s | lr 5.00e-04 | gnorm 2.989 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.6430 | top1 38.02% | top3 59.55% | top5 68.97% | 1058.9 img/s | lr 5.00e-04 | gnorm 2.992 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.6430 | top1 38.02% | top3 59.55% | top5 68.97% | lr 5.00e-04 | grad_norm 2.992 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 2.1246 | top1 44.50% | top3 66.26% | top5 75.52%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 44.500000)
# Epoch time: 0.74 min
#
# === Epoch 7/100 ===
# [train step 600/704] loss 2.5423 | top1 41.57% | top3 62.62% | top5 71.56% | 1063.3 img/s | lr 5.00e-04 | gnorm 2.825 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.5360 | top1 41.64% | top3 62.59% | top5 71.60% | 1062.7 img/s | lr 4.99e-04 | gnorm 2.827 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.5360 | top1 41.64% | top3 62.59% | top5 71.60% | lr 4.99e-04 | grad_norm 2.827 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 1.8983 | top1 49.62% | top3 72.00% | top5 80.18%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 49.620000)
# Epoch time: 0.74 min
#
# === Epoch 8/100 ===
# [train step 600/704] loss 2.4521 | top1 44.32% | top3 65.36% | top5 74.02% | 1056.9 img/s | lr 4.99e-04 | gnorm 2.733 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.4506 | top1 44.39% | top3 65.40% | top5 73.98% | 1054.6 img/s | lr 4.99e-04 | gnorm 2.728 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.4506 | top1 44.39% | top3 65.40% | top5 73.98% | lr 4.99e-04 | grad_norm 2.728 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 1.8302 | top1 51.68% | top3 73.44% | top5 80.92%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 51.680000)
# Epoch time: 0.75 min
#
# === Epoch 9/100 ===
# [train step 600/704] loss 2.3090 | top1 48.06% | top3 68.50% | top5 76.78% | 1051.1 img/s | lr 4.98e-04 | gnorm 2.687 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.2904 | top1 48.33% | top3 68.78% | top5 77.08% | 1053.1 img/s | lr 4.98e-04 | gnorm 2.695 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.2904 | top1 48.33% | top3 68.78% | top5 77.08% | lr 4.98e-04 | grad_norm 2.695 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.80 GiB
# [Val]   loss 1.7446 | top1 53.24% | top3 74.66% | top5 83.08%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.80 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 53.240000)
# Epoch time: 0.75 min
#
# === Epoch 10/100 ===
# [train step 600/704] loss 2.2304 | top1 49.29% | top3 69.73% | top5 77.65% | 1055.6 img/s | lr 4.97e-04 | gnorm 2.678 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.2006 | top1 49.90% | top3 70.29% | top5 78.16% | 1057.0 img/s | lr 4.97e-04 | gnorm 2.698 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.2006 | top1 49.90% | top3 70.29% | top5 78.16% | lr 4.97e-04 | grad_norm 2.698 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.6538 | top1 55.58% | top3 76.54% | top5 84.44%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 55.580000)
# Epoch time: 0.75 min
#
# === Epoch 11/100 ===
# [train step 600/704] loss 2.1113 | top1 51.41% | top3 72.04% | top5 79.56% | 1044.1 img/s | lr 4.95e-04 | gnorm 2.695 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.1183 | top1 51.37% | top3 71.95% | top5 79.45% | 1046.5 img/s | lr 4.95e-04 | gnorm 2.696 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.1183 | top1 51.37% | top3 71.95% | top5 79.45% | lr 4.95e-04 | grad_norm 2.696 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.5782 | top1 57.82% | top3 78.68% | top5 85.14%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 57.820000)
# Epoch time: 0.75 min
#
# === Epoch 12/100 ===
# [train step 600/704] loss 2.1557 | top1 52.21% | top3 71.99% | top5 79.32% | 1065.2 img/s | lr 4.94e-04 | gnorm 2.613 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 2.1377 | top1 52.53% | top3 72.30% | top5 79.56% | 1063.5 img/s | lr 4.93e-04 | gnorm 2.619 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 2.1377 | top1 52.53% | top3 72.30% | top5 79.56% | lr 4.93e-04 | grad_norm 2.619 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.5345 | top1 58.62% | top3 79.48% | top5 85.82%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 58.620000)
# Epoch time: 0.74 min
#
# === Epoch 13/100 ===
# [train step 600/704] loss 1.9926 | top1 55.03% | top3 74.59% | top5 81.51% | 1057.6 img/s | lr 4.92e-04 | gnorm 2.647 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.9866 | top1 55.16% | top3 74.73% | top5 81.73% | 1058.1 img/s | lr 4.91e-04 | gnorm 2.657 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.9866 | top1 55.16% | top3 74.73% | top5 81.73% | lr 4.91e-04 | grad_norm 2.657 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.4860 | top1 60.04% | top3 79.90% | top5 86.38%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 60.040000)
# Epoch time: 0.74 min
#
# === Epoch 14/100 ===
# [train step 600/704] loss 1.9465 | top1 56.28% | top3 75.73% | top5 82.40% | 1054.7 img/s | lr 4.89e-04 | gnorm 2.658 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.9614 | top1 55.92% | top3 75.28% | top5 81.97% | 1054.7 img/s | lr 4.89e-04 | gnorm 2.654 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.9614 | top1 55.92% | top3 75.28% | top5 81.97% | lr 4.89e-04 | grad_norm 2.654 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.4834 | top1 60.08% | top3 80.56% | top5 87.00%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 15/100 ===
# [train step 600/704] loss 1.9186 | top1 57.44% | top3 76.71% | top5 83.21% | 1062.7 img/s | lr 4.87e-04 | gnorm 2.645 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.8915 | top1 57.93% | top3 77.15% | top5 83.53% | 1063.4 img/s | lr 4.86e-04 | gnorm 2.657 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.8915 | top1 57.93% | top3 77.15% | top5 83.53% | lr 4.86e-04 | grad_norm 2.657 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.4045 | top1 61.42% | top3 81.42% | top5 87.66%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 61.420000)
# Epoch time: 0.74 min
#
# === Epoch 16/100 ===
# [train step 600/704] loss 1.8586 | top1 59.38% | top3 77.99% | top5 84.24% | 1066.1 img/s | lr 4.84e-04 | gnorm 2.614 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.8647 | top1 59.17% | top3 77.78% | top5 84.12% | 1064.3 img/s | lr 4.84e-04 | gnorm 2.623 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.8647 | top1 59.17% | top3 77.78% | top5 84.12% | lr 4.84e-04 | grad_norm 2.623 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.3824 | top1 63.22% | top3 81.48% | top5 87.60%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 63.220000)
# Epoch time: 0.74 min
#
# === Epoch 17/100 ===
# [train step 600/704] loss 1.7837 | top1 60.85% | top3 79.22% | top5 85.19% | 1060.3 img/s | lr 4.81e-04 | gnorm 2.618 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.7877 | top1 60.78% | top3 79.15% | top5 85.08% | 1057.9 img/s | lr 4.81e-04 | gnorm 2.620 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.7877 | top1 60.78% | top3 79.15% | top5 85.08% | lr 4.81e-04 | grad_norm 2.620 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.3577 | top1 63.00% | top3 82.06% | top5 88.58%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 18/100 ===
# [train step 600/704] loss 1.8375 | top1 60.73% | top3 78.58% | top5 84.72% | 1052.9 img/s | lr 4.78e-04 | gnorm 2.594 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.8323 | top1 60.96% | top3 78.82% | top5 84.90% | 1052.7 img/s | lr 4.77e-04 | gnorm 2.598 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.8323 | top1 60.96% | top3 78.82% | top5 84.90% | lr 4.77e-04 | grad_norm 2.598 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.3976 | top1 62.90% | top3 82.28% | top5 88.00%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 19/100 ===
# [train step 600/704] loss 1.6766 | top1 63.09% | top3 80.81% | top5 86.55% | 1051.1 img/s | lr 4.74e-04 | gnorm 2.637 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.6807 | top1 63.12% | top3 80.81% | top5 86.53% | 1047.9 img/s | lr 4.74e-04 | gnorm 2.641 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.6807 | top1 63.12% | top3 80.81% | top5 86.53% | lr 4.74e-04 | grad_norm 2.641 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 2.75 GiB | reserved 3.81 GiB
# [Val]   loss 1.2932 | top1 64.80% | top3 83.62% | top5 89.20%
# [Val]   mem_peak alloc 1.38 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 64.800000)
# Epoch time: 0.76 min
#
# === Epoch 20/100 ===
# [train step 600/704] loss 1.7325 | top1 63.32% | top3 80.96% | top5 86.59% | 1040.3 img/s | lr 4.71e-04 | gnorm 2.585 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.7382 | top1 63.04% | top3 80.57% | top5 86.18% | 1038.2 img/s | lr 4.70e-04 | gnorm 2.601 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.7382 | top1 63.04% | top3 80.57% | top5 86.18% | lr 4.70e-04 | grad_norm 2.601 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.2755 | top1 65.64% | top3 83.52% | top5 89.60%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 65.640000)
# Epoch time: 0.76 min
#
# === Epoch 21/100 ===
# [train step 600/704] loss 1.6255 | top1 65.12% | top3 81.98% | top5 87.22% | 1044.0 img/s | lr 4.66e-04 | gnorm 2.620 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.6459 | top1 64.65% | top3 81.74% | top5 87.03% | 1044.1 img/s | lr 4.66e-04 | gnorm 2.620 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.6459 | top1 64.65% | top3 81.74% | top5 87.03% | lr 4.66e-04 | grad_norm 2.620 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.3112 | top1 64.38% | top3 83.24% | top5 88.66%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 22/100 ===
# [train step 600/704] loss 1.6835 | top1 64.52% | top3 81.67% | top5 87.01% | 1035.8 img/s | lr 4.62e-04 | gnorm 2.574 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.6978 | top1 64.25% | top3 81.37% | top5 86.80% | 1036.3 img/s | lr 4.62e-04 | gnorm 2.586 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.6978 | top1 64.25% | top3 81.37% | top5 86.80% | lr 4.62e-04 | grad_norm 2.586 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.3242 | top1 65.44% | top3 83.92% | top5 89.16%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.76 min
#
# === Epoch 23/100 ===
# [train step 600/704] loss 1.6595 | top1 65.72% | top3 82.50% | top5 87.63% | 1039.8 img/s | lr 4.58e-04 | gnorm 2.567 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.6595 | top1 65.65% | top3 82.49% | top5 87.65% | 1040.8 img/s | lr 4.57e-04 | gnorm 2.582 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.6595 | top1 65.65% | top3 82.49% | top5 87.65% | lr 4.57e-04 | grad_norm 2.582 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.2465 | top1 66.10% | top3 84.36% | top5 89.86%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 66.100000)
# Epoch time: 0.76 min
#
# === Epoch 24/100 ===
# [train step 600/704] loss 1.5998 | top1 66.30% | top3 82.77% | top5 87.83% | 1046.8 img/s | lr 4.53e-04 | gnorm 2.629 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5972 | top1 66.13% | top3 82.56% | top5 87.62% | 1046.9 img/s | lr 4.52e-04 | gnorm 2.639 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5972 | top1 66.13% | top3 82.56% | top5 87.62% | lr 4.52e-04 | grad_norm 2.639 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.2769 | top1 66.22% | top3 84.72% | top5 89.54%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 66.220000)
# Epoch time: 0.76 min
#
# === Epoch 25/100 ===
# [train step 600/704] loss 1.5282 | top1 68.45% | top3 84.57% | top5 89.11% | 1041.6 img/s | lr 4.48e-04 | gnorm 2.611 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5304 | top1 68.20% | top3 84.40% | top5 88.97% | 1039.7 img/s | lr 4.47e-04 | gnorm 2.614 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5304 | top1 68.20% | top3 84.40% | top5 88.97% | lr 4.47e-04 | grad_norm 2.614 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.2234 | top1 67.20% | top3 84.38% | top5 89.98%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 67.200000)
# Epoch time: 0.76 min
#
# === Epoch 26/100 ===
# [train step 600/704] loss 1.5812 | top1 68.41% | top3 83.93% | top5 88.64% | 1052.2 img/s | lr 4.43e-04 | gnorm 2.567 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5692 | top1 68.56% | top3 84.20% | top5 88.91% | 1052.3 img/s | lr 4.42e-04 | gnorm 2.588 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5692 | top1 68.56% | top3 84.20% | top5 88.91% | lr 4.42e-04 | grad_norm 2.588 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.2166 | top1 66.58% | top3 85.38% | top5 90.28%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 27/100 ===
# [train step 600/704] loss 1.5541 | top1 68.17% | top3 83.61% | top5 88.38% | 1056.9 img/s | lr 4.38e-04 | gnorm 2.599 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5523 | top1 68.31% | top3 83.76% | top5 88.57% | 1053.4 img/s | lr 4.37e-04 | gnorm 2.615 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5523 | top1 68.31% | top3 83.76% | top5 88.57% | lr 4.37e-04 | grad_norm 2.615 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1880 | top1 67.92% | top3 85.74% | top5 90.52%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 67.920000)
# Epoch time: 0.75 min
#
# === Epoch 28/100 ===
# [train step 600/704] loss 1.5918 | top1 68.39% | top3 83.89% | top5 88.58% | 1052.9 img/s | lr 4.32e-04 | gnorm 2.587 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5680 | top1 68.64% | top3 84.20% | top5 88.82% | 1051.2 img/s | lr 4.31e-04 | gnorm 2.613 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5680 | top1 68.64% | top3 84.20% | top5 88.82% | lr 4.31e-04 | grad_norm 2.613 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1753 | top1 67.66% | top3 85.52% | top5 90.76%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 29/100 ===
# [train step 600/704] loss 1.5078 | top1 69.94% | top3 85.36% | top5 89.69% | 1050.1 img/s | lr 4.26e-04 | gnorm 2.613 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.5109 | top1 69.80% | top3 85.21% | top5 89.56% | 1049.4 img/s | lr 4.25e-04 | gnorm 2.640 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.5109 | top1 69.80% | top3 85.21% | top5 89.56% | lr 4.25e-04 | grad_norm 2.640 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.2127 | top1 67.90% | top3 85.36% | top5 90.52%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 30/100 ===
# [train step 600/704] loss 1.4714 | top1 70.56% | top3 85.35% | top5 89.70% | 1053.9 img/s | lr 4.20e-04 | gnorm 2.597 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.4582 | top1 70.58% | top3 85.48% | top5 89.84% | 1049.6 img/s | lr 4.19e-04 | gnorm 2.621 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.4582 | top1 70.58% | top3 85.48% | top5 89.84% | lr 4.19e-04 | grad_norm 2.621 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1918 | top1 68.72% | top3 85.52% | top5 89.98%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 68.720000)
# Epoch time: 0.75 min
#
# === Epoch 31/100 ===
# [train step 600/704] loss 1.4262 | top1 71.41% | top3 85.57% | top5 89.66% | 1052.5 img/s | lr 4.14e-04 | gnorm 2.648 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.4126 | top1 71.69% | top3 85.77% | top5 89.85% | 1050.0 img/s | lr 4.13e-04 | gnorm 2.660 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.4126 | top1 71.69% | top3 85.77% | top5 89.85% | lr 4.13e-04 | grad_norm 2.660 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1710 | top1 68.32% | top3 85.54% | top5 90.50%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 32/100 ===
# [train step 600/704] loss 1.3920 | top1 72.18% | top3 86.44% | top5 90.60% | 1048.8 img/s | lr 4.08e-04 | gnorm 2.647 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3832 | top1 72.49% | top3 86.68% | top5 90.75% | 1049.0 img/s | lr 4.07e-04 | gnorm 2.654 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3832 | top1 72.49% | top3 86.68% | top5 90.75% | lr 4.07e-04 | grad_norm 2.654 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1922 | top1 68.54% | top3 85.96% | top5 90.58%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 33/100 ===
# [train step 600/704] loss 1.3759 | top1 73.21% | top3 86.91% | top5 90.89% | 1046.9 img/s | lr 4.01e-04 | gnorm 2.611 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3934 | top1 72.92% | top3 86.70% | top5 90.71% | 1047.8 img/s | lr 4.00e-04 | gnorm 2.618 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3934 | top1 72.92% | top3 86.70% | top5 90.71% | lr 4.00e-04 | grad_norm 2.618 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1554 | top1 68.70% | top3 85.84% | top5 90.64%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 34/100 ===
# [train step 600/704] loss 1.3328 | top1 73.77% | top3 87.25% | top5 90.99% | 1046.9 img/s | lr 3.95e-04 | gnorm 2.641 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3556 | top1 73.33% | top3 86.93% | top5 90.71% | 1045.6 img/s | lr 3.94e-04 | gnorm 2.662 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3556 | top1 73.33% | top3 86.93% | top5 90.71% | lr 3.94e-04 | grad_norm 2.662 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1752 | top1 69.40% | top3 85.74% | top5 90.18%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 69.400000)
# Epoch time: 0.75 min
#
# === Epoch 35/100 ===
# [train step 600/704] loss 1.3332 | top1 74.18% | top3 87.21% | top5 90.77% | 1048.2 img/s | lr 3.88e-04 | gnorm 2.616 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3352 | top1 74.15% | top3 87.38% | top5 90.93% | 1043.6 img/s | lr 3.87e-04 | gnorm 2.628 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3352 | top1 74.15% | top3 87.38% | top5 90.93% | lr 3.87e-04 | grad_norm 2.628 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1422 | top1 69.72% | top3 86.24% | top5 91.24%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 69.720000)
# Epoch time: 0.76 min
#
# === Epoch 36/100 ===
# [train step 600/704] loss 1.3270 | top1 75.20% | top3 88.15% | top5 91.76% | 1043.2 img/s | lr 3.81e-04 | gnorm 2.638 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3402 | top1 74.90% | top3 87.97% | top5 91.62% | 1040.8 img/s | lr 3.80e-04 | gnorm 2.646 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3402 | top1 74.90% | top3 87.97% | top5 91.62% | lr 3.80e-04 | grad_norm 2.646 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1558 | top1 69.62% | top3 86.20% | top5 91.00%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 37/100 ===
# [train step 600/704] loss 1.3846 | top1 74.09% | top3 87.46% | top5 91.05% | 1036.6 img/s | lr 3.74e-04 | gnorm 2.579 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3758 | top1 73.92% | top3 87.24% | top5 90.86% | 1035.9 img/s | lr 3.73e-04 | gnorm 2.607 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3758 | top1 73.92% | top3 87.24% | top5 90.86% | lr 3.73e-04 | grad_norm 2.607 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1627 | top1 69.86% | top3 86.48% | top5 91.08%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 69.860000)
# Epoch time: 0.76 min
#
# === Epoch 38/100 ===
# [train step 600/704] loss 1.3657 | top1 74.04% | top3 87.06% | top5 90.77% | 1050.2 img/s | lr 3.67e-04 | gnorm 2.593 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3535 | top1 74.35% | top3 87.33% | top5 90.99% | 1046.5 img/s | lr 3.66e-04 | gnorm 2.618 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3535 | top1 74.35% | top3 87.33% | top5 90.99% | lr 3.66e-04 | grad_norm 2.618 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1140 | top1 70.86% | top3 86.76% | top5 91.06%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 70.860000)
# Epoch time: 0.75 min
#
# === Epoch 39/100 ===
# [train step 600/704] loss 1.3005 | top1 75.93% | top3 88.18% | top5 91.60% | 1044.9 img/s | lr 3.59e-04 | gnorm 2.618 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2728 | top1 76.31% | top3 88.53% | top5 91.84% | 1044.9 img/s | lr 3.58e-04 | gnorm 2.636 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2728 | top1 76.31% | top3 88.53% | top5 91.84% | lr 3.58e-04 | grad_norm 2.636 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0975 | top1 70.68% | top3 86.80% | top5 91.84%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 40/100 ===
# [train step 600/704] loss 1.3113 | top1 75.77% | top3 88.11% | top5 91.50% | 1042.0 img/s | lr 3.52e-04 | gnorm 2.621 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.3057 | top1 76.00% | top3 88.39% | top5 91.80% | 1041.2 img/s | lr 3.51e-04 | gnorm 2.645 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.3057 | top1 76.00% | top3 88.39% | top5 91.80% | lr 3.51e-04 | grad_norm 2.645 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1325 | top1 69.82% | top3 86.60% | top5 91.42%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 41/100 ===
# [train step 600/704] loss 1.2323 | top1 76.86% | top3 88.66% | top5 91.89% | 1039.3 img/s | lr 3.44e-04 | gnorm 2.606 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2595 | top1 76.52% | top3 88.40% | top5 91.74% | 1036.6 img/s | lr 3.43e-04 | gnorm 2.615 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2595 | top1 76.52% | top3 88.40% | top5 91.74% | lr 3.43e-04 | grad_norm 2.615 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0990 | top1 70.48% | top3 86.86% | top5 91.64%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 42/100 ===
# [train step 600/704] loss 1.2405 | top1 77.26% | top3 88.65% | top5 91.83% | 1040.3 img/s | lr 3.37e-04 | gnorm 2.608 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2628 | top1 76.86% | top3 88.45% | top5 91.68% | 1041.0 img/s | lr 3.35e-04 | gnorm 2.614 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2628 | top1 76.86% | top3 88.45% | top5 91.68% | lr 3.35e-04 | grad_norm 2.614 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1238 | top1 70.44% | top3 87.16% | top5 91.26%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 43/100 ===
# [train step 600/704] loss 1.2146 | top1 77.82% | top3 89.42% | top5 92.40% | 1042.3 img/s | lr 3.29e-04 | gnorm 2.625 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2098 | top1 77.87% | top3 89.45% | top5 92.47% | 1041.7 img/s | lr 3.28e-04 | gnorm 2.650 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2098 | top1 77.87% | top3 89.45% | top5 92.47% | lr 3.28e-04 | grad_norm 2.650 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0678 | top1 72.14% | top3 87.42% | top5 91.62%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 72.140000)
# Epoch time: 0.76 min
#
# === Epoch 44/100 ===
# [train step 600/704] loss 1.2228 | top1 77.73% | top3 88.96% | top5 91.91% | 1038.4 img/s | lr 3.21e-04 | gnorm 2.612 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2295 | top1 77.72% | top3 89.06% | top5 91.98% | 1036.9 img/s | lr 3.20e-04 | gnorm 2.613 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2295 | top1 77.72% | top3 89.06% | top5 91.98% | lr 3.20e-04 | grad_norm 2.613 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1355 | top1 70.42% | top3 87.00% | top5 91.44%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 45/100 ===
# [train step 600/704] loss 1.3008 | top1 76.53% | top3 87.80% | top5 91.10% | 1045.8 img/s | lr 3.13e-04 | gnorm 2.564 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2813 | top1 76.92% | top3 88.19% | top5 91.40% | 1044.3 img/s | lr 3.12e-04 | gnorm 2.593 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2813 | top1 76.92% | top3 88.19% | top5 91.40% | lr 3.12e-04 | grad_norm 2.593 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1111 | top1 70.54% | top3 86.60% | top5 90.82%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 46/100 ===
# [train step 600/704] loss 1.1695 | top1 79.39% | top3 89.71% | top5 92.60% | 1038.4 img/s | lr 3.05e-04 | gnorm 2.561 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1461 | top1 79.57% | top3 89.89% | top5 92.73% | 1036.6 img/s | lr 3.04e-04 | gnorm 2.600 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1461 | top1 79.57% | top3 89.89% | top5 92.73% | lr 3.04e-04 | grad_norm 2.600 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1086 | top1 70.42% | top3 87.40% | top5 91.50%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 47/100 ===
# [train step 600/704] loss 1.1620 | top1 79.31% | top3 89.99% | top5 92.94% | 1035.8 img/s | lr 2.97e-04 | gnorm 2.630 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1595 | top1 79.42% | top3 90.01% | top5 92.96% | 1035.4 img/s | lr 2.96e-04 | gnorm 2.626 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1595 | top1 79.42% | top3 90.01% | top5 92.96% | lr 2.96e-04 | grad_norm 2.626 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0863 | top1 72.02% | top3 87.74% | top5 91.80%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.76 min
#
# === Epoch 48/100 ===
# [train step 600/704] loss 1.2393 | top1 78.45% | top3 89.33% | top5 92.35% | 1047.4 img/s | lr 2.89e-04 | gnorm 2.599 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2513 | top1 78.11% | top3 89.08% | top5 92.12% | 1045.7 img/s | lr 2.87e-04 | gnorm 2.618 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2513 | top1 78.11% | top3 89.08% | top5 92.12% | lr 2.87e-04 | grad_norm 2.618 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0952 | top1 71.68% | top3 87.02% | top5 91.42%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 49/100 ===
# [train step 600/704] loss 1.1553 | top1 79.27% | top3 89.71% | top5 92.47% | 1043.1 img/s | lr 2.81e-04 | gnorm 2.624 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1601 | top1 79.31% | top3 89.85% | top5 92.61% | 1045.8 img/s | lr 2.79e-04 | gnorm 2.633 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1601 | top1 79.31% | top3 89.85% | top5 92.61% | lr 2.79e-04 | grad_norm 2.633 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.1485 | top1 71.42% | top3 86.66% | top5 91.18%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 50/100 ===
# [train step 600/704] loss 1.1362 | top1 80.18% | top3 90.22% | top5 93.01% | 1045.7 img/s | lr 2.72e-04 | gnorm 2.557 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1466 | top1 80.03% | top3 90.15% | top5 92.90% | 1044.7 img/s | lr 2.71e-04 | gnorm 2.581 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1466 | top1 80.03% | top3 90.15% | top5 92.90% | lr 2.71e-04 | grad_norm 2.581 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0657 | top1 72.28% | top3 87.34% | top5 92.10%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 72.280000)
# Epoch time: 0.75 min
#
# === Epoch 51/100 ===
# [train step 600/704] loss 1.1233 | top1 81.18% | top3 90.76% | top5 93.29% | 1040.2 img/s | lr 2.64e-04 | gnorm 2.553 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1405 | top1 80.68% | top3 90.47% | top5 93.09% | 1037.8 img/s | lr 2.63e-04 | gnorm 2.578 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1405 | top1 80.68% | top3 90.47% | top5 93.09% | lr 2.63e-04 | grad_norm 2.578 | clip 99.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0544 | top1 72.42% | top3 87.90% | top5 92.34%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 72.420000)
# Epoch time: 0.76 min
#
# === Epoch 52/100 ===
# [train step 600/704] loss 1.0926 | top1 81.54% | top3 91.19% | top5 93.71% | 1046.3 img/s | lr 2.56e-04 | gnorm 2.564 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1069 | top1 81.10% | top3 90.80% | top5 93.37% | 1045.6 img/s | lr 2.55e-04 | gnorm 2.573 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1069 | top1 81.10% | top3 90.80% | top5 93.37% | lr 2.55e-04 | grad_norm 2.573 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0582 | top1 71.68% | top3 87.92% | top5 91.96%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.75 min
#
# === Epoch 53/100 ===
# [train step 600/704] loss 1.2308 | top1 78.91% | top3 89.16% | top5 92.22% | 1039.8 img/s | lr 2.48e-04 | gnorm 2.560 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.2408 | top1 78.95% | top3 89.25% | top5 92.26% | 1035.9 img/s | lr 2.46e-04 | gnorm 2.575 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.2408 | top1 78.95% | top3 89.25% | top5 92.26% | lr 2.46e-04 | grad_norm 2.575 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0826 | top1 73.02% | top3 87.38% | top5 91.50%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 73.020000)
# Epoch time: 0.76 min
#
# === Epoch 54/100 ===
# [train step 600/704] loss 1.1409 | top1 80.34% | top3 90.04% | top5 92.72% | 1035.0 img/s | lr 2.39e-04 | gnorm 2.574 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1284 | top1 80.68% | top3 90.27% | top5 92.93% | 1032.8 img/s | lr 2.38e-04 | gnorm 2.579 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1284 | top1 80.68% | top3 90.27% | top5 92.93% | lr 2.38e-04 | grad_norm 2.579 | clip 99.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0683 | top1 72.02% | top3 87.54% | top5 91.70%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.76 min
#
# === Epoch 55/100 ===
# [train step 600/704] loss 1.1013 | top1 82.02% | top3 91.12% | top5 93.50% | 1048.9 img/s | lr 2.31e-04 | gnorm 2.532 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1091 | top1 81.59% | top3 90.79% | top5 93.22% | 1050.4 img/s | lr 2.30e-04 | gnorm 2.542 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1091 | top1 81.59% | top3 90.79% | top5 93.22% | lr 2.30e-04 | grad_norm 2.542 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0335 | top1 73.20% | top3 87.96% | top5 92.46%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 73.200000)
# Epoch time: 0.75 min
#
# === Epoch 56/100 ===
# [train step 600/704] loss 1.0482 | top1 82.73% | top3 91.68% | top5 94.04% | 1062.1 img/s | lr 2.23e-04 | gnorm 2.548 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0560 | top1 82.57% | top3 91.55% | top5 93.98% | 1061.9 img/s | lr 2.22e-04 | gnorm 2.553 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0560 | top1 82.57% | top3 91.55% | top5 93.98% | lr 2.22e-04 | grad_norm 2.553 | clip 99.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0633 | top1 72.20% | top3 87.42% | top5 91.60%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 57/100 ===
# [train step 600/704] loss 1.0999 | top1 82.25% | top3 91.20% | top5 93.68% | 1077.1 img/s | lr 2.15e-04 | gnorm 2.466 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0985 | top1 82.10% | top3 91.09% | top5 93.61% | 1077.7 img/s | lr 2.14e-04 | gnorm 2.484 | clip 99.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0985 | top1 82.10% | top3 91.09% | top5 93.61% | lr 2.14e-04 | grad_norm 2.484 | clip 99.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0247 | top1 72.94% | top3 87.66% | top5 91.80%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.73 min
#
# === Epoch 58/100 ===
# [train step 600/704] loss 1.1321 | top1 81.30% | top3 90.39% | top5 93.07% | 1070.5 img/s | lr 2.07e-04 | gnorm 2.507 | clip 99.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.1674 | top1 80.75% | top3 89.98% | top5 92.83% | 1071.3 img/s | lr 2.05e-04 | gnorm 2.527 | clip 99.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.1674 | top1 80.75% | top3 89.98% | top5 92.83% | lr 2.05e-04 | grad_norm 2.527 | clip 99.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0777 | top1 72.26% | top3 87.38% | top5 91.74%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.73 min
#
# === Epoch 59/100 ===
# [train step 600/704] loss 1.0518 | top1 83.56% | top3 91.93% | top5 94.22% | 1074.3 img/s | lr 1.98e-04 | gnorm 2.492 | clip 99.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0648 | top1 83.31% | top3 91.80% | top5 94.16% | 1075.7 img/s | lr 1.97e-04 | gnorm 2.510 | clip 99.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0648 | top1 83.31% | top3 91.80% | top5 94.16% | lr 1.97e-04 | grad_norm 2.510 | clip 99.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0307 | top1 72.40% | top3 88.00% | top5 92.22%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.73 min
#
# === Epoch 60/100 ===
# [train step 600/704] loss 1.0398 | top1 82.80% | top3 91.04% | top5 93.48% | 1076.5 img/s | lr 1.90e-04 | gnorm 2.484 | clip 99.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0660 | top1 82.36% | top3 90.79% | top5 93.29% | 1076.0 img/s | lr 1.89e-04 | gnorm 2.497 | clip 99.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0660 | top1 82.36% | top3 90.79% | top5 93.29% | lr 1.89e-04 | grad_norm 2.497 | clip 99.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0047 | top1 73.50% | top3 88.22% | top5 92.40%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 73.500000)
# Epoch time: 0.73 min
#
# === Epoch 61/100 ===
# [train step 600/704] loss 1.0815 | top1 82.70% | top3 91.27% | top5 93.72% | 1068.2 img/s | lr 1.82e-04 | gnorm 2.475 | clip 98.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0714 | top1 82.94% | top3 91.49% | top5 93.87% | 1071.0 img/s | lr 1.81e-04 | gnorm 2.496 | clip 98.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0714 | top1 82.94% | top3 91.49% | top5 93.87% | lr 1.81e-04 | grad_norm 2.496 | clip 98.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0328 | top1 73.14% | top3 87.58% | top5 92.00%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.73 min
#
# === Epoch 62/100 ===
# [train step 600/704] loss 1.0871 | top1 82.36% | top3 90.89% | top5 93.29% | 1063.9 img/s | lr 1.75e-04 | gnorm 2.488 | clip 98.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0541 | top1 83.13% | top3 91.36% | top5 93.69% | 1067.4 img/s | lr 1.73e-04 | gnorm 2.491 | clip 99.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0541 | top1 83.13% | top3 91.36% | top5 93.69% | lr 1.73e-04 | grad_norm 2.491 | clip 99.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 0.9976 | top1 73.94% | top3 88.26% | top5 92.50%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Best saved to best_No_Outlooker.pt (val top1 = 73.940000)
# Epoch time: 0.74 min
#
# === Epoch 63/100 ===
# [train step 600/704] loss 1.0602 | top1 83.43% | top3 91.56% | top5 93.88% | 1058.5 img/s | lr 1.67e-04 | gnorm 2.480 | clip 98.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0557 | top1 83.68% | top3 91.80% | top5 94.10% | 1059.1 img/s | lr 1.66e-04 | gnorm 2.485 | clip 99.0% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0557 | top1 83.68% | top3 91.80% | top5 94.10% | lr 1.66e-04 | grad_norm 2.485 | clip 99.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0256 | top1 73.26% | top3 87.98% | top5 92.02%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.74 min
#
# === Epoch 64/100 ===
# [train step 600/704] loss 1.0210 | top1 84.34% | top3 92.16% | top5 94.29% | 1068.3 img/s | lr 1.59e-04 | gnorm 2.441 | clip 97.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0184 | top1 84.22% | top3 92.03% | top5 94.21% | 1066.7 img/s | lr 1.58e-04 | gnorm 2.452 | clip 97.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0184 | top1 84.22% | top3 92.03% | top5 94.21% | lr 1.58e-04 | grad_norm 2.452 | clip 97.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# [Val]   loss 1.0158 | top1 73.24% | top3 88.44% | top5 92.48%
# [Val]   mem_peak alloc 0.46 GiB | reserved 3.81 GiB
# Epoch time: 0.73 min
#
# === Epoch 65/100 ===
# [train step 600/704] loss 0.9679 | top1 84.26% | top3 91.86% | top5 94.11% | 1062.6 img/s | lr 1.51e-04 | gnorm 2.406 | clip 98.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9871 | top1 84.15% | top3 91.90% | top5 94.21% | 1064.0 img/s | lr 1.50e-04 | gnorm 2.440 | clip 98.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9871 | top1 84.15% | top3 91.90% | top5 94.21% | lr 1.50e-04 | grad_norm 2.440 | clip 98.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.83 GiB | reserved 3.81 GiB
# ...
# [Train] loss 1.0007 | top1 85.16% | top3 92.32% | top5 94.50% | lr 8.77e-05 | grad_norm 2.332 | clip 92.8% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9702 | top1 74.44% | top3 88.48% | top5 92.46%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 75/100 ===
# [train step 600/704] loss 1.0315 | top1 84.88% | top3 92.10% | top5 94.46% | 1679.9 img/s | lr 8.24e-05 | gnorm 2.358 | clip 92.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 1.0302 | top1 84.83% | top3 92.10% | top5 94.42% | 1668.2 img/s | lr 8.15e-05 | gnorm 2.368 | clip 92.8% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 1.0302 | top1 84.83% | top3 92.10% | top5 94.42% | lr 8.15e-05 | grad_norm 2.368 | clip 92.8% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9939 | top1 75.24% | top3 88.42% | top5 92.22%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Best saved to best_Plain_MBConv.pt (val top1 = 75.240000)
# Epoch time: 0.48 min
#
# === Epoch 76/100 ===
# [train step 600/704] loss 0.9167 | top1 86.39% | top3 92.99% | top5 95.00% | 1668.6 img/s | lr 7.64e-05 | gnorm 2.268 | clip 90.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9457 | top1 86.01% | top3 92.77% | top5 94.84% | 1675.6 img/s | lr 7.55e-05 | gnorm 2.299 | clip 90.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9457 | top1 86.01% | top3 92.77% | top5 94.84% | lr 7.55e-05 | grad_norm 2.299 | clip 90.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9683 | top1 75.08% | top3 89.00% | top5 92.80%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.47 min
#
# === Epoch 77/100 ===
# [train step 600/704] loss 1.0043 | top1 84.86% | top3 91.97% | top5 94.11% | 1605.9 img/s | lr 7.06e-05 | gnorm 2.361 | clip 92.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9876 | top1 85.10% | top3 92.15% | top5 94.24% | 1613.2 img/s | lr 6.98e-05 | gnorm 2.345 | clip 91.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9876 | top1 85.10% | top3 92.15% | top5 94.24% | lr 6.98e-05 | grad_norm 2.345 | clip 91.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9587 | top1 75.54% | top3 89.08% | top5 92.62%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Best saved to best_Plain_MBConv.pt (val top1 = 75.540000)
# Epoch time: 0.49 min
#
# === Epoch 78/100 ===
# [train step 600/704] loss 0.9713 | top1 86.26% | top3 93.13% | top5 95.08% | 1632.6 img/s | lr 6.50e-05 | gnorm 2.268 | clip 89.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9737 | top1 86.40% | top3 93.21% | top5 95.14% | 1639.3 img/s | lr 6.42e-05 | gnorm 2.276 | clip 89.8% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9737 | top1 86.40% | top3 93.21% | top5 95.14% | lr 6.42e-05 | grad_norm 2.276 | clip 89.8% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 1.0130 | top1 75.32% | top3 89.14% | top5 92.52%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 79/100 ===
# [train step 600/704] loss 0.9862 | top1 86.58% | top3 93.12% | top5 94.97% | 1655.2 img/s | lr 5.96e-05 | gnorm 2.256 | clip 88.7% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9994 | top1 86.34% | top3 93.01% | top5 94.90% | 1659.5 img/s | lr 5.88e-05 | gnorm 2.282 | clip 88.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9994 | top1 86.34% | top3 93.01% | top5 94.90% | lr 5.88e-05 | grad_norm 2.282 | clip 88.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 1.0274 | top1 75.20% | top3 88.30% | top5 92.26%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 80/100 ===
# [train step 600/704] loss 0.9155 | top1 86.91% | top3 93.20% | top5 95.11% | 1673.0 img/s | lr 5.44e-05 | gnorm 2.183 | clip 88.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9324 | top1 86.50% | top3 93.00% | top5 94.95% | 1675.1 img/s | lr 5.36e-05 | gnorm 2.200 | clip 87.9% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9324 | top1 86.50% | top3 93.00% | top5 94.95% | lr 5.36e-05 | grad_norm 2.200 | clip 87.9% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9562 | top1 75.42% | top3 89.04% | top5 92.62%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.47 min
#
# === Epoch 81/100 ===
# [train step 600/704] loss 0.9439 | top1 87.36% | top3 93.71% | top5 95.56% | 1661.8 img/s | lr 4.94e-05 | gnorm 2.197 | clip 87.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9464 | top1 87.16% | top3 93.55% | top5 95.38% | 1654.1 img/s | lr 4.87e-05 | gnorm 2.232 | clip 87.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9464 | top1 87.16% | top3 93.55% | top5 95.38% | lr 4.87e-05 | grad_norm 2.232 | clip 87.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9825 | top1 75.82% | top3 88.92% | top5 92.56%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Best saved to best_Plain_MBConv.pt (val top1 = 75.820000)
# Epoch time: 0.48 min
#
# === Epoch 82/100 ===
# [train step 600/704] loss 0.8813 | top1 87.30% | top3 93.37% | top5 95.24% | 1662.6 img/s | lr 4.46e-05 | gnorm 2.121 | clip 84.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9130 | top1 86.74% | top3 93.08% | top5 95.08% | 1662.5 img/s | lr 4.39e-05 | gnorm 2.170 | clip 84.9% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9130 | top1 86.74% | top3 93.08% | top5 95.08% | lr 4.39e-05 | grad_norm 2.170 | clip 84.9% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9322 | top1 75.66% | top3 89.14% | top5 92.66%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 83/100 ===
# [train step 600/704] loss 0.9429 | top1 87.11% | top3 93.46% | top5 95.31% | 1634.7 img/s | lr 4.01e-05 | gnorm 2.183 | clip 86.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9382 | top1 87.20% | top3 93.55% | top5 95.37% | 1645.3 img/s | lr 3.94e-05 | gnorm 2.205 | clip 86.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9382 | top1 87.20% | top3 93.55% | top5 95.37% | lr 3.94e-05 | grad_norm 2.205 | clip 86.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9759 | top1 75.42% | top3 88.80% | top5 92.48%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 84/100 ===
# [train step 600/704] loss 1.0087 | top1 86.10% | top3 92.78% | top5 94.81% | 1665.0 img/s | lr 3.57e-05 | gnorm 2.174 | clip 85.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9791 | top1 86.54% | top3 93.07% | top5 95.00% | 1671.1 img/s | lr 3.51e-05 | gnorm 2.170 | clip 85.2% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9791 | top1 86.54% | top3 93.07% | top5 95.00% | lr 3.51e-05 | grad_norm 2.170 | clip 85.2% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9919 | top1 76.00% | top3 89.02% | top5 92.48%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Best saved to best_Plain_MBConv.pt (val top1 = 76.000000)
# Epoch time: 0.48 min
#
# === Epoch 85/100 ===
# [train step 600/704] loss 0.9140 | top1 87.36% | top3 93.55% | top5 95.36% | 1642.7 img/s | lr 3.17e-05 | gnorm 2.162 | clip 83.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9179 | top1 87.19% | top3 93.47% | top5 95.30% | 1649.2 img/s | lr 3.11e-05 | gnorm 2.187 | clip 84.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9179 | top1 87.19% | top3 93.47% | top5 95.30% | lr 3.11e-05 | grad_norm 2.187 | clip 84.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9476 | top1 75.76% | top3 88.92% | top5 92.24%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 86/100 ===
# [train step 600/704] loss 0.9352 | top1 86.67% | top3 92.96% | top5 95.05% | 1653.0 img/s | lr 2.78e-05 | gnorm 2.162 | clip 82.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9178 | top1 86.69% | top3 92.96% | top5 95.04% | 1658.9 img/s | lr 2.73e-05 | gnorm 2.177 | clip 82.5% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9178 | top1 86.69% | top3 92.96% | top5 95.04% | lr 2.73e-05 | grad_norm 2.177 | clip 82.5% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9542 | top1 74.94% | top3 89.22% | top5 92.80%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 87/100 ===
# [train step 600/704] loss 0.9069 | top1 88.11% | top3 94.19% | top5 95.90% | 1618.6 img/s | lr 2.42e-05 | gnorm 2.128 | clip 82.3% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9205 | top1 87.94% | top3 94.07% | top5 95.81% | 1628.3 img/s | lr 2.37e-05 | gnorm 2.167 | clip 82.8% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9205 | top1 87.94% | top3 94.07% | top5 95.81% | lr 2.37e-05 | grad_norm 2.167 | clip 82.8% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9397 | top1 75.84% | top3 89.36% | top5 93.24%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.49 min
#
# === Epoch 88/100 ===
# [train step 600/704] loss 0.9669 | top1 86.42% | top3 93.04% | top5 95.10% | 1665.5 img/s | lr 2.09e-05 | gnorm 2.190 | clip 83.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9577 | top1 86.66% | top3 93.14% | top5 95.16% | 1670.1 img/s | lr 2.04e-05 | gnorm 2.174 | clip 82.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9577 | top1 86.66% | top3 93.14% | top5 95.16% | lr 2.04e-05 | grad_norm 2.174 | clip 82.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9603 | top1 75.36% | top3 88.98% | top5 92.70%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 89/100 ===
# [train step 600/704] loss 0.9221 | top1 87.45% | top3 93.58% | top5 95.47% | 1698.9 img/s | lr 1.78e-05 | gnorm 2.126 | clip 82.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9386 | top1 87.41% | top3 93.58% | top5 95.53% | 1693.9 img/s | lr 1.73e-05 | gnorm 2.129 | clip 82.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9386 | top1 87.41% | top3 93.58% | top5 95.53% | lr 1.73e-05 | grad_norm 2.129 | clip 82.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9346 | top1 76.10% | top3 89.30% | top5 92.72%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Best saved to best_Plain_MBConv.pt (val top1 = 76.100000)
# Epoch time: 0.47 min
#
# === Epoch 90/100 ===
# [train step 600/704] loss 0.9339 | top1 86.96% | top3 93.24% | top5 95.19% | 1616.9 img/s | lr 1.49e-05 | gnorm 2.127 | clip 83.2% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9382 | top1 86.92% | top3 93.26% | top5 95.22% | 1627.6 img/s | lr 1.45e-05 | gnorm 2.142 | clip 82.7% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9382 | top1 86.92% | top3 93.26% | top5 95.22% | lr 1.45e-05 | grad_norm 2.142 | clip 82.7% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9362 | top1 76.02% | top3 89.22% | top5 92.68%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.49 min
#
# === Epoch 91/100 ===
# [train step 600/704] loss 0.9302 | top1 87.46% | top3 93.71% | top5 95.47% | 1626.9 img/s | lr 1.23e-05 | gnorm 2.095 | clip 81.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9248 | top1 87.41% | top3 93.58% | top5 95.36% | 1619.5 img/s | lr 1.20e-05 | gnorm 2.093 | clip 80.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9248 | top1 87.41% | top3 93.58% | top5 95.36% | lr 1.20e-05 | grad_norm 2.093 | clip 80.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9325 | top1 75.82% | top3 89.32% | top5 92.82%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.49 min
#
# === Epoch 92/100 ===
# [train step 600/704] loss 0.9351 | top1 86.97% | top3 93.28% | top5 95.14% | 1677.6 img/s | lr 1.00e-05 | gnorm 2.090 | clip 81.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9395 | top1 86.76% | top3 93.13% | top5 95.03% | 1657.6 img/s | lr 9.68e-06 | gnorm 2.099 | clip 80.8% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9395 | top1 86.76% | top3 93.13% | top5 95.03% | lr 9.68e-06 | grad_norm 2.099 | clip 80.8% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9450 | top1 75.94% | top3 89.28% | top5 92.88%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 93/100 ===
# [train step 600/704] loss 0.8767 | top1 88.77% | top3 94.41% | top5 96.05% | 1634.1 img/s | lr 7.94e-06 | gnorm 2.057 | clip 80.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8931 | top1 88.21% | top3 94.05% | top5 95.78% | 1642.3 img/s | lr 7.66e-06 | gnorm 2.080 | clip 80.3% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8931 | top1 88.21% | top3 94.05% | top5 95.78% | lr 7.66e-06 | grad_norm 2.080 | clip 80.3% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9537 | top1 75.66% | top3 89.08% | top5 92.72%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 94/100 ===
# [train step 600/704] loss 0.8147 | top1 89.14% | top3 94.37% | top5 95.98% | 1622.3 img/s | lr 6.14e-06 | gnorm 1.988 | clip 77.8% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8285 | top1 89.07% | top3 94.35% | top5 96.00% | 1638.2 img/s | lr 5.90e-06 | gnorm 2.014 | clip 78.4% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8285 | top1 89.07% | top3 94.35% | top5 96.00% | lr 5.90e-06 | grad_norm 2.014 | clip 78.4% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9785 | top1 74.96% | top3 89.08% | top5 92.54%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Epoch time: 0.48 min
#
# === Epoch 95/100 ===
# [train step 600/704] loss 0.8387 | top1 89.00% | top3 94.34% | top5 95.99% | 1645.9 img/s | lr 4.61e-06 | gnorm 2.049 | clip 79.0% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.8379 | top1 89.17% | top3 94.54% | top5 96.13% | 1644.8 img/s | lr 4.40e-06 | gnorm 2.042 | clip 78.6% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.8379 | top1 89.17% | top3 94.54% | top5 96.13% | lr 4.40e-06 | grad_norm 2.042 | clip 78.6% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
# [Val]   loss 0.9403 | top1 76.32% | top3 89.18% | top5 92.68%
# [Val]   mem_peak alloc 0.43 GiB | reserved 1.81 GiB
# Best saved to best_Plain_MBConv.pt (val top1 = 76.320000)
# Epoch time: 0.49 min
#
# === Epoch 96/100 ===
# [train step 600/704] loss 0.9102 | top1 87.92% | top3 93.92% | top5 95.68% | 1704.0 img/s | lr 3.34e-06 | gnorm 2.033 | clip 78.5% | oflow 0 | nonfinite 0 | scale 1.0
# [train step 704/704] loss 0.9258 | top1 87.82% | top3 93.89% | top5 95.70% | 1706.3 img/s | lr 3.18e-06 | gnorm 2.047 | clip 78.1% | oflow 0 | nonfinite 0 | scale 1.0
# [Train] loss 0.9258 | top1 87.82% | top3 93.89% | top5 95.70% | lr 3.18e-06 | grad_norm 2.047 | clip 78.1% | amp_overflows 0 | nonfinite_loss 0 | scale 1.0
# [Train] mem_peak alloc 1.56 GiB | reserved 1.81 GiB
