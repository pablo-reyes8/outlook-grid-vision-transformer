# %%
import sys, os

root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_path not in sys.path:
    sys.path.append(root_path)

# %%
from data.load_cifrar100 import *

train_loader, val_loader, test_loader = get_cifar100_dataloaders(
    batch_size=64,
    data_dir="./data",
    num_workers=2,
    val_split=0.1,
    img_size=32 , seed=7)

# %%
def count_trainable_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ---

# %%
import torch.nn as nn
import timm
from src.training.train_full_model import * 
from src.training.metrics import * 
from src.training.eval_one_epoch_logs import *

device = 'cuda'
model_v2_s = timm.create_model("efficientnetv2_s", pretrained=False, num_classes=100)
out_channels = model_v2_s.conv_stem.out_channels

model_v2_s.conv_stem = nn.Conv2d(
    in_channels=3, 
    out_channels=out_channels, 
    kernel_size=3, 
    stride=1,      
    padding=1, 
    bias=False)

model_v2_s = model_v2_s.to(device)

n_params = sum(p.numel() for p in model_v2_s.parameters() if p.requires_grad)
print(f"Trainable parameters: {n_params:,}")
# Out:
# Trainable parameters: 20,305,588

# %%
history, _ = train_model(
        model=model_v2_s,
        train_loader=train_loader,
        epochs=100,
        val_loader=val_loader,
        device=device,

        lr=5e-4,
        weight_decay=0.05,

        # Mixed Precision
        autocast_dtype="fp16" if device == "cuda" else "fp32",
        use_amp=(device == "cuda"),
        grad_clip_norm=1.0,

        warmup_ratio=0.05,
        min_lr=1e-6,

        label_smoothing=0.1,
        save_path= "best_model_vit1.pt",
        last_path = "last_model_vit1.pt",

        print_every=400,
        mix_prob=0.5,
        mixup_alpha=0.8,
        cutmix_alpha=1.0,

        num_classes=100,
        channels_last=True)
# Out:
# === Run config ===
# device=cuda | amp=True | autocast_dtype=fp16 | channels_last=True
# epochs=100 | steps/epoch=704 | total_steps=70400 | warmup_steps=3520
# batch_size=64 | input_shape=(64, 3, 32, 32) | num_classes=100
# opt=AdamW | lr=0.0005 | wd=0.05 | grad_clip_norm=1.0
# aug: mix_prob=0.5 | mixup_alpha=0.8 | cutmix_alpha=1.0 | label_smoothing=0.1
# ==================
#
# === Epoch 1/100 ===
# [train step 400/704] loss 4.8129 | top1 1.23% | top3 3.40% | top5 5.61% | 698.9 img/s | lr 5.68e-05 | gnorm inf | clip 100.0% | oflow 4 | nonfinite 0 | scale 4096.0
# [train step 704/704] loss 4.7567 | top1 1.32% | top3 3.70% | top5 5.99% | 699.6 img/s | lr 1.00e-04 | gnorm inf | clip 100.0% | oflow 4 | nonfinite 0 | scale 4096.0
# [Train] loss 4.7567 | top1 1.32% | top3 3.70% | top5 5.99% | lr 1.00e-04 | grad_norm inf | clip 100.0% | amp_overflows 4 | nonfinite_loss 0 | scale 4096.0
# [Train] mem_peak alloc 1.53 GiB | reserved 3.16 GiB
# [Val]   loss 7.2097 | top1 1.08% | top3 4.02% | top5 6.66%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 1.08%)
# Epoch time: 1.14 min
#
# === Epoch 2/100 ===
# [train step 400/704] loss 4.5445 | top1 2.47% | top3 7.02% | top5 10.95% | 720.1 img/s | lr 1.57e-04 | gnorm 18.142 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [train step 704/704] loss 4.4560 | top1 3.44% | top3 9.22% | top5 14.05% | 723.5 img/s | lr 2.00e-04 | gnorm 12.326 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [Train] loss 4.4560 | top1 3.44% | top3 9.22% | top5 14.05% | lr 2.00e-04 | grad_norm 12.326 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 4096.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 4.3726 | top1 5.56% | top3 15.06% | top5 22.34%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 5.56%)
# Epoch time: 1.11 min
#
# === Epoch 3/100 ===
# [train step 400/704] loss 4.2262 | top1 6.32% | top3 15.84% | top5 22.92% | 727.4 img/s | lr 2.57e-04 | gnorm 3.399 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [train step 704/704] loss 4.1851 | top1 7.03% | top3 17.08% | top5 24.46% | 729.1 img/s | lr 3.00e-04 | gnorm 3.360 | clip 100.0% | oflow 0 | nonfinite 0 | scale 8192.0
# [Train] loss 4.1851 | top1 7.03% | top3 17.08% | top5 24.46% | lr 3.00e-04 | grad_norm 3.360 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 8192.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 4.2209 | top1 10.44% | top3 22.90% | top5 31.34%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 10.44%)
# Epoch time: 1.09 min
#
# === Epoch 4/100 ===
# [train step 400/704] loss 4.0265 | top1 9.98% | top3 22.18% | top5 30.47% | 682.4 img/s | lr 3.57e-04 | gnorm 3.081 | clip 100.0% | oflow 0 | nonfinite 0 | scale 8192.0
# [train step 704/704] loss 4.0026 | top1 10.48% | top3 22.98% | top5 31.30% | 692.7 img/s | lr 4.00e-04 | gnorm 3.178 | clip 100.0% | oflow 0 | nonfinite 0 | scale 8192.0
# [Train] loss 4.0026 | top1 10.48% | top3 22.98% | top5 31.30% | lr 4.00e-04 | grad_norm 3.178 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 8192.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 4.9234 | top1 13.96% | top3 27.30% | top5 36.96%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 13.96%)
# Epoch time: 1.15 min
#
# === Epoch 5/100 ===
# [train step 400/704] loss 3.9077 | top1 12.34% | top3 25.63% | top5 34.31% | 704.6 img/s | lr 4.57e-04 | gnorm 3.033 | clip 100.0% | oflow 0 | nonfinite 0 | scale 8192.0
# [train step 704/704] loss 3.8750 | top1 12.87% | top3 26.52% | top5 35.38% | 709.4 img/s | lr 5.00e-04 | gnorm 3.244 | clip 100.0% | oflow 0 | nonfinite 0 | scale 8192.0
# [Train] loss 3.8750 | top1 12.87% | top3 26.52% | top5 35.38% | lr 5.00e-04 | grad_norm 3.244 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 8192.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.8017 | top1 15.04% | top3 30.20% | top5 40.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 15.04%)
# Epoch time: 1.13 min
#
# === Epoch 6/100 ===
# [train step 400/704] loss 3.7809 | top1 14.84% | top3 29.34% | top5 39.06% | 713.1 img/s | lr 5.00e-04 | gnorm 3.207 | clip 100.0% | oflow 0 | nonfinite 0 | scale 8192.0
# [train step 704/704] loss 3.7464 | top1 15.41% | top3 30.08% | top5 39.56% | 707.0 img/s | lr 5.00e-04 | gnorm 3.068 | clip 100.0% | oflow 0 | nonfinite 0 | scale 16384.0
# [Train] loss 3.7464 | top1 15.41% | top3 30.08% | top5 39.56% | lr 5.00e-04 | grad_norm 3.068 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 16384.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.5083 | top1 18.52% | top3 35.52% | top5 45.70%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 18.52%)
# Epoch time: 1.13 min
#
# === Epoch 7/100 ===
# [train step 400/704] loss 3.6012 | top1 17.78% | top3 34.20% | top5 44.12% | 697.1 img/s | lr 5.00e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 8192.0
# [train step 704/704] loss 3.5745 | top1 18.20% | top3 34.97% | top5 44.98% | 706.3 img/s | lr 4.99e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 8192.0
# [Train] loss 3.5745 | top1 18.20% | top3 34.97% | top5 44.98% | lr 4.99e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 8192.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.2149 | top1 21.98% | top3 40.42% | top5 51.22%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 21.98%)
# Epoch time: 1.13 min
#
# === Epoch 8/100 ===
# [train step 400/704] loss 3.4183 | top1 21.49% | top3 39.01% | top5 49.27% | 710.1 img/s | lr 4.99e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 4096.0
# [train step 704/704] loss 3.4180 | top1 21.50% | top3 39.15% | top5 49.48% | 705.2 img/s | lr 4.99e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 4096.0
# [Train] loss 3.4180 | top1 21.50% | top3 39.15% | top5 49.48% | lr 4.99e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 4096.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.9412 | top1 23.84% | top3 43.40% | top5 54.92%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 23.84%)
# Epoch time: 1.13 min
#
# === Epoch 9/100 ===
# [train step 400/704] loss 3.3168 | top1 23.65% | top3 42.57% | top5 52.92% | 703.3 img/s | lr 4.98e-04 | gnorm 3.715 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [train step 704/704] loss 3.2924 | top1 24.01% | top3 42.77% | top5 52.94% | 700.7 img/s | lr 4.98e-04 | gnorm 3.721 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [Train] loss 3.2924 | top1 24.01% | top3 42.77% | top5 52.94% | lr 4.98e-04 | grad_norm 3.721 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 4096.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.4456 | top1 27.94% | top3 48.74% | top5 59.00%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 27.94%)
# Epoch time: 1.14 min
#
# === Epoch 10/100 ===
# [train step 400/704] loss 3.2328 | top1 25.33% | top3 44.46% | top5 54.41% | 734.7 img/s | lr 4.97e-04 | gnorm 3.887 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [train step 704/704] loss 3.1941 | top1 26.13% | top3 45.38% | top5 55.46% | 716.9 img/s | lr 4.97e-04 | gnorm 3.845 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [Train] loss 3.1941 | top1 26.13% | top3 45.38% | top5 55.46% | lr 4.97e-04 | grad_norm 3.845 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 4096.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.4808 | top1 29.84% | top3 50.72% | top5 61.60%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 29.84%)
# Epoch time: 1.11 min
#
# === Epoch 11/100 ===
# [train step 400/704] loss 3.1091 | top1 28.31% | top3 48.37% | top5 58.60% | 708.3 img/s | lr 4.96e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 2048.0
# [train step 704/704] loss 3.0827 | top1 28.86% | top3 48.93% | top5 58.94% | 712.6 img/s | lr 4.95e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 2048.0
# [Train] loss 3.0827 | top1 28.86% | top3 48.93% | top5 58.94% | lr 4.95e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 2048.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.5189 | top1 32.80% | top3 54.06% | top5 63.72%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 32.80%)
# Epoch time: 1.12 min
#
# === Epoch 12/100 ===
# [train step 400/704] loss 2.9785 | top1 30.48% | top3 51.15% | top5 61.09% | 702.6 img/s | lr 4.94e-04 | gnorm 4.785 | clip 100.0% | oflow 0 | nonfinite 0 | scale 2048.0
# [train step 704/704] loss 2.9539 | top1 30.94% | top3 51.57% | top5 61.38% | 714.8 img/s | lr 4.93e-04 | gnorm 4.771 | clip 100.0% | oflow 0 | nonfinite 0 | scale 2048.0
# [Train] loss 2.9539 | top1 30.94% | top3 51.57% | top5 61.38% | lr 4.93e-04 | grad_norm 4.771 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 2048.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 3.0940 | top1 35.18% | top3 56.32% | top5 66.90%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 35.18%)
# Epoch time: 1.12 min
#
# === Epoch 13/100 ===
# [train step 400/704] loss 2.9185 | top1 32.68% | top3 52.80% | top5 62.55% | 722.7 img/s | lr 4.92e-04 | gnorm 4.512 | clip 100.0% | oflow 0 | nonfinite 0 | scale 2048.0
# [train step 704/704] loss 2.9149 | top1 32.22% | top3 52.54% | top5 62.37% | 726.0 img/s | lr 4.91e-04 | gnorm 4.498 | clip 100.0% | oflow 0 | nonfinite 0 | scale 4096.0
# [Train] loss 2.9149 | top1 32.22% | top3 52.54% | top5 62.37% | lr 4.91e-04 | grad_norm 4.498 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 4096.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.6396 | top1 36.78% | top3 58.74% | top5 68.86%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 36.78%)
# Epoch time: 1.10 min
#
# === Epoch 14/100 ===
# [train step 400/704] loss 2.8576 | top1 33.88% | top3 54.22% | top5 63.70% | 700.1 img/s | lr 4.90e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 2048.0
# [train step 704/704] loss 2.8488 | top1 33.92% | top3 54.46% | top5 64.12% | 708.1 img/s | lr 4.89e-04 | gnorm inf | clip 100.0% | oflow 2 | nonfinite 0 | scale 1024.0
# [Train] loss 2.8488 | top1 33.92% | top3 54.46% | top5 64.12% | lr 4.89e-04 | grad_norm inf | clip 100.0% | amp_overflows 2 | nonfinite_loss 0 | scale 1024.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.4584 | top1 37.40% | top3 60.14% | top5 70.28%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 37.40%)
# Epoch time: 1.13 min
#
# === Epoch 15/100 ===
# [train step 400/704] loss 2.7526 | top1 35.30% | top3 56.56% | top5 66.15% | 725.3 img/s | lr 4.88e-04 | gnorm 3.929 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [train step 704/704] loss 2.7500 | top1 35.58% | top3 56.53% | top5 66.21% | 717.7 img/s | lr 4.86e-04 | gnorm 4.400 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [Train] loss 2.7500 | top1 35.58% | top3 56.53% | top5 66.21% | lr 4.86e-04 | grad_norm 4.400 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1024.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.5260 | top1 40.92% | top3 62.94% | top5 72.14%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 40.92%)
# Epoch time: 1.11 min
#
# === Epoch 16/100 ===
# [train step 400/704] loss 2.6906 | top1 36.76% | top3 58.02% | top5 67.28% | 715.3 img/s | lr 4.85e-04 | gnorm 4.436 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [train step 704/704] loss 2.6465 | top1 37.55% | top3 58.71% | top5 68.09% | 717.1 img/s | lr 4.84e-04 | gnorm 4.766 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [Train] loss 2.6465 | top1 37.55% | top3 58.71% | top5 68.09% | lr 4.84e-04 | grad_norm 4.766 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1024.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.3079 | top1 41.90% | top3 62.80% | top5 72.16%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 41.90%)
# Epoch time: 1.11 min
#
# === Epoch 17/100 ===
# [train step 400/704] loss 2.6562 | top1 38.02% | top3 59.15% | top5 68.62% | 725.8 img/s | lr 4.82e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.6666 | top1 37.83% | top3 58.96% | top5 68.43% | 718.2 img/s | lr 4.81e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 512.0
# [Train] loss 2.6666 | top1 37.83% | top3 58.96% | top5 68.43% | lr 4.81e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.2486 | top1 42.26% | top3 64.52% | top5 73.36%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 42.26%)
# Epoch time: 1.11 min
#
# === Epoch 18/100 ===
# [train step 400/704] loss 2.5313 | top1 40.17% | top3 61.52% | top5 70.61% | 724.2 img/s | lr 4.79e-04 | gnorm 5.660 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.5662 | top1 39.44% | top3 60.59% | top5 69.80% | 720.8 img/s | lr 4.77e-04 | gnorm 6.222 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 2.5662 | top1 39.44% | top3 60.59% | top5 69.80% | lr 4.77e-04 | grad_norm 6.222 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.3784 | top1 41.96% | top3 64.00% | top5 74.50%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 19/100 ===
# [train step 400/704] loss 2.4963 | top1 41.56% | top3 62.72% | top5 71.53% | 714.5 img/s | lr 4.75e-04 | gnorm 5.837 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.5191 | top1 41.16% | top3 62.13% | top5 71.04% | 696.2 img/s | lr 4.74e-04 | gnorm 5.659 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 2.5191 | top1 41.16% | top3 62.13% | top5 71.04% | lr 4.74e-04 | grad_norm 5.659 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.2400 | top1 43.50% | top3 65.86% | top5 74.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 43.50%)
# Epoch time: 1.14 min
#
# === Epoch 20/100 ===
# [train step 400/704] loss 2.5054 | top1 41.35% | top3 62.91% | top5 71.98% | 712.1 img/s | lr 4.72e-04 | gnorm 4.637 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [train step 704/704] loss 2.5407 | top1 41.05% | top3 62.28% | top5 71.28% | 719.8 img/s | lr 4.70e-04 | gnorm 5.434 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [Train] loss 2.5407 | top1 41.05% | top3 62.28% | top5 71.28% | lr 4.70e-04 | grad_norm 5.434 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1024.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.2769 | top1 44.94% | top3 66.16% | top5 74.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 44.94%)
# Epoch time: 1.11 min
#
# === Epoch 21/100 ===
# [train step 400/704] loss 2.4682 | top1 42.89% | top3 64.06% | top5 72.64% | 720.2 img/s | lr 4.68e-04 | gnorm 5.518 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [train step 704/704] loss 2.4722 | top1 42.48% | top3 63.50% | top5 72.20% | 715.2 img/s | lr 4.66e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 512.0
# [Train] loss 2.4722 | top1 42.48% | top3 63.50% | top5 72.20% | lr 4.66e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.1421 | top1 45.48% | top3 68.28% | top5 77.60%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 45.48%)
# Epoch time: 1.12 min
#
# === Epoch 22/100 ===
# [train step 400/704] loss 2.4683 | top1 43.01% | top3 63.91% | top5 72.72% | 676.7 img/s | lr 4.63e-04 | gnorm 5.240 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.4777 | top1 42.64% | top3 63.74% | top5 72.37% | 689.4 img/s | lr 4.62e-04 | gnorm 4.696 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 2.4777 | top1 42.64% | top3 63.74% | top5 72.37% | lr 4.62e-04 | grad_norm 4.696 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.1371 | top1 46.08% | top3 68.62% | top5 77.18%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 46.08%)
# Epoch time: 1.15 min
#
# === Epoch 23/100 ===
# [train step 400/704] loss 2.3752 | top1 44.84% | top3 65.59% | top5 74.21% | 707.2 img/s | lr 4.59e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 2.4041 | top1 44.28% | top3 64.97% | top5 73.66% | 715.0 img/s | lr 4.57e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [Train] loss 2.4041 | top1 44.28% | top3 64.97% | top5 73.66% | lr 4.57e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.1288 | top1 47.38% | top3 69.26% | top5 77.24%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 47.38%)
# Epoch time: 1.12 min
#
# === Epoch 24/100 ===
# [train step 400/704] loss 2.4226 | top1 44.26% | top3 64.82% | top5 73.41% | 697.0 img/s | lr 4.54e-04 | gnorm 7.483 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 2.4085 | top1 44.47% | top3 65.36% | top5 73.82% | 703.2 img/s | lr 4.52e-04 | gnorm 8.055 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 2.4085 | top1 44.47% | top3 65.36% | top5 73.82% | lr 4.52e-04 | grad_norm 8.055 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.0665 | top1 47.90% | top3 69.40% | top5 77.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 47.90%)
# Epoch time: 1.14 min
#
# === Epoch 25/100 ===
# [train step 400/704] loss 2.2969 | top1 46.76% | top3 67.41% | top5 75.37% | 695.9 img/s | lr 4.50e-04 | gnorm 9.489 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 2.3429 | top1 45.95% | top3 66.67% | top5 74.98% | 703.0 img/s | lr 4.47e-04 | gnorm 9.723 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 2.3429 | top1 45.95% | top3 66.67% | top5 74.98% | lr 4.47e-04 | grad_norm 9.723 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.0483 | top1 49.64% | top3 71.40% | top5 79.88%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 49.64%)
# Epoch time: 1.13 min
#
# === Epoch 26/100 ===
# [train step 400/704] loss 2.2869 | top1 47.31% | top3 68.20% | top5 76.38% | 717.7 img/s | lr 4.44e-04 | gnorm 5.003 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.2933 | top1 47.06% | top3 67.87% | top5 75.91% | 709.6 img/s | lr 4.42e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [Train] loss 2.2933 | top1 47.06% | top3 67.87% | top5 75.91% | lr 4.42e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.8736 | top1 50.62% | top3 71.80% | top5 80.00%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 50.62%)
# Epoch time: 1.13 min
#
# === Epoch 27/100 ===
# [train step 400/704] loss 2.1865 | top1 48.62% | top3 69.60% | top5 77.70% | 718.6 img/s | lr 4.39e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 2.2227 | top1 47.88% | top3 68.78% | top5 77.00% | 709.3 img/s | lr 4.37e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 128.0
# [Train] loss 2.2227 | top1 47.88% | top3 68.78% | top5 77.00% | lr 4.37e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.9269 | top1 49.82% | top3 71.74% | top5 80.32%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.12 min
#
# === Epoch 28/100 ===
# [train step 400/704] loss 2.2170 | top1 48.82% | top3 69.63% | top5 77.38% | 726.9 img/s | lr 4.34e-04 | gnorm 5.324 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 2.2336 | top1 48.38% | top3 69.32% | top5 77.06% | 712.2 img/s | lr 4.31e-04 | gnorm 5.216 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 2.2336 | top1 48.38% | top3 69.32% | top5 77.06% | lr 4.31e-04 | grad_norm 5.216 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 2.0075 | top1 50.60% | top3 71.50% | top5 79.90%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.12 min
#
# === Epoch 29/100 ===
# [train step 400/704] loss 2.1793 | top1 49.67% | top3 70.23% | top5 78.02% | 702.8 img/s | lr 4.28e-04 | gnorm 8.028 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 2.2343 | top1 48.85% | top3 69.45% | top5 77.26% | 701.3 img/s | lr 4.25e-04 | gnorm 6.499 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 2.2343 | top1 48.85% | top3 69.45% | top5 77.26% | lr 4.25e-04 | grad_norm 6.499 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.9596 | top1 49.86% | top3 70.68% | top5 78.86%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.14 min
#
# === Epoch 30/100 ===
# [train step 400/704] loss 2.1162 | top1 51.48% | top3 71.50% | top5 79.20% | 708.6 img/s | lr 4.22e-04 | gnorm 5.375 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 2.0997 | top1 51.45% | top3 71.62% | top5 79.18% | 695.1 img/s | lr 4.19e-04 | gnorm 5.612 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 2.0997 | top1 51.45% | top3 71.62% | top5 79.18% | lr 4.19e-04 | grad_norm 5.612 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.8422 | top1 51.60% | top3 72.52% | top5 80.96%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 51.60%)
# Epoch time: 1.15 min
#
# === Epoch 31/100 ===
# [train step 400/704] loss 2.1468 | top1 50.76% | top3 71.21% | top5 78.75% | 723.6 img/s | lr 4.16e-04 | gnorm 9.942 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 2.1536 | top1 50.66% | top3 71.33% | top5 78.82% | 716.1 img/s | lr 4.13e-04 | gnorm 9.079 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 2.1536 | top1 50.66% | top3 71.33% | top5 78.82% | lr 4.13e-04 | grad_norm 9.079 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.8870 | top1 51.66% | top3 72.28% | top5 80.40%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 51.66%)
# Epoch time: 1.12 min
#
# === Epoch 32/100 ===
# [train step 400/704] loss 2.1948 | top1 50.09% | top3 70.40% | top5 78.10% | 702.1 img/s | lr 4.10e-04 | gnorm 4.663 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 2.1380 | top1 51.16% | top3 71.58% | top5 79.10% | 713.6 img/s | lr 4.07e-04 | gnorm 4.661 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 2.1380 | top1 51.16% | top3 71.58% | top5 79.10% | lr 4.07e-04 | grad_norm 4.661 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.9392 | top1 52.04% | top3 73.06% | top5 80.82%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 52.04%)
# Epoch time: 1.12 min
#
# === Epoch 33/100 ===
# [train step 400/704] loss 2.0326 | top1 53.30% | top3 73.16% | top5 80.54% | 721.5 img/s | lr 4.03e-04 | gnorm 5.288 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.0441 | top1 53.15% | top3 73.11% | top5 80.54% | 707.4 img/s | lr 4.00e-04 | gnorm 5.262 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 2.0441 | top1 53.15% | top3 73.11% | top5 80.54% | lr 4.00e-04 | grad_norm 5.262 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.8026 | top1 52.16% | top3 73.22% | top5 81.92%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 52.16%)
# Epoch time: 1.13 min
#
# === Epoch 34/100 ===
# [train step 400/704] loss 2.0555 | top1 53.25% | top3 73.41% | top5 80.41% | 710.3 img/s | lr 3.97e-04 | gnorm 6.632 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 2.0688 | top1 52.88% | top3 73.02% | top5 80.18% | 702.0 img/s | lr 3.94e-04 | gnorm 6.017 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 2.0688 | top1 52.88% | top3 73.02% | top5 80.18% | lr 3.94e-04 | grad_norm 6.017 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.7915 | top1 54.16% | top3 75.14% | top5 83.10%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 54.16%)
# Epoch time: 1.14 min
#
# === Epoch 35/100 ===
# [train step 400/704] loss 1.9805 | top1 55.11% | top3 74.72% | top5 81.83% | 727.1 img/s | lr 3.90e-04 | gnorm 6.191 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [train step 704/704] loss 1.9930 | top1 54.67% | top3 74.46% | top5 81.46% | 723.4 img/s | lr 3.87e-04 | gnorm 5.700 | clip 100.0% | oflow 0 | nonfinite 0 | scale 1024.0
# [Train] loss 1.9930 | top1 54.67% | top3 74.46% | top5 81.46% | lr 3.87e-04 | grad_norm 5.700 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 1024.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.9255 | top1 53.72% | top3 73.46% | top5 81.24%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 36/100 ===
# [train step 400/704] loss 2.0173 | top1 54.69% | top3 74.13% | top5 80.98% | 723.1 img/s | lr 3.83e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 1.9774 | top1 55.21% | top3 74.93% | top5 81.69% | 721.7 img/s | lr 3.80e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 512.0
# [Train] loss 1.9774 | top1 55.21% | top3 74.93% | top5 81.69% | lr 3.80e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.7436 | top1 53.98% | top3 74.82% | top5 82.64%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 37/100 ===
# [train step 400/704] loss 2.0004 | top1 54.76% | top3 74.22% | top5 81.15% | 695.2 img/s | lr 3.76e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.9887 | top1 55.27% | top3 74.68% | top5 81.73% | 685.3 img/s | lr 3.73e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [Train] loss 1.9887 | top1 55.27% | top3 74.68% | top5 81.73% | lr 3.73e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.8067 | top1 54.42% | top3 75.10% | top5 81.96%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 54.42%)
# Epoch time: 1.16 min
#
# === Epoch 38/100 ===
# [train step 400/704] loss 1.9468 | top1 56.28% | top3 75.75% | top5 82.28% | 695.4 img/s | lr 3.69e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.9623 | top1 55.74% | top3 75.16% | top5 81.80% | 711.1 img/s | lr 3.66e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 128.0
# [Train] loss 1.9623 | top1 55.74% | top3 75.16% | top5 81.80% | lr 3.66e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.7645 | top1 54.02% | top3 74.66% | top5 82.74%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.12 min
#
# === Epoch 39/100 ===
# [train step 400/704] loss 1.8926 | top1 57.19% | top3 76.46% | top5 82.91% | 704.6 img/s | lr 3.61e-04 | gnorm 7.120 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.8628 | top1 57.60% | top3 76.66% | top5 83.27% | 710.7 img/s | lr 3.58e-04 | gnorm 8.068 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.8628 | top1 57.60% | top3 76.66% | top5 83.27% | lr 3.58e-04 | grad_norm 8.068 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6900 | top1 56.44% | top3 75.82% | top5 82.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 56.44%)
# Epoch time: 1.12 min
#
# === Epoch 40/100 ===
# [train step 400/704] loss 1.8779 | top1 58.50% | top3 77.05% | top5 83.40% | 717.3 img/s | lr 3.54e-04 | gnorm 5.761 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.8766 | top1 58.40% | top3 77.27% | top5 83.58% | 719.1 img/s | lr 3.51e-04 | gnorm 6.500 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.8766 | top1 58.40% | top3 77.27% | top5 83.58% | lr 3.51e-04 | grad_norm 6.500 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.7165 | top1 55.14% | top3 75.14% | top5 82.82%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.11 min
#
# === Epoch 41/100 ===
# [train step 400/704] loss 1.8508 | top1 58.46% | top3 77.14% | top5 83.29% | 699.5 img/s | lr 3.46e-04 | gnorm 6.307 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.8327 | top1 58.90% | top3 77.70% | top5 83.91% | 712.5 img/s | lr 3.43e-04 | gnorm 9.303 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.8327 | top1 58.90% | top3 77.70% | top5 83.91% | lr 3.43e-04 | grad_norm 9.303 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.7042 | top1 56.06% | top3 76.64% | top5 83.54%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.11 min
#
# === Epoch 42/100 ===
# [train step 400/704] loss 1.8214 | top1 59.66% | top3 77.57% | top5 83.79% | 717.2 img/s | lr 3.39e-04 | gnorm 11.433 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.8304 | top1 59.64% | top3 77.70% | top5 83.88% | 706.2 img/s | lr 3.35e-04 | gnorm 10.511 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.8304 | top1 59.64% | top3 77.70% | top5 83.88% | lr 3.35e-04 | grad_norm 10.511 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6620 | top1 56.98% | top3 76.16% | top5 83.32%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 56.98%)
# Epoch time: 1.13 min
#
# === Epoch 43/100 ===
# [train step 400/704] loss 1.9006 | top1 58.70% | top3 76.67% | top5 82.81% | 718.4 img/s | lr 3.31e-04 | gnorm 6.170 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.8656 | top1 59.24% | top3 77.24% | top5 83.36% | 720.5 img/s | lr 3.28e-04 | gnorm 5.702 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 1.8656 | top1 59.24% | top3 77.24% | top5 83.36% | lr 3.28e-04 | grad_norm 5.702 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.7025 | top1 55.62% | top3 76.14% | top5 82.74%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 44/100 ===
# [train step 400/704] loss 1.8277 | top1 60.45% | top3 78.48% | top5 84.27% | 713.5 img/s | lr 3.23e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.8403 | top1 60.29% | top3 78.54% | top5 84.24% | 719.4 img/s | lr 3.20e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [Train] loss 1.8403 | top1 60.29% | top3 78.54% | top5 84.24% | lr 3.20e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6841 | top1 55.72% | top3 75.64% | top5 82.88%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 45/100 ===
# [train step 400/704] loss 1.6365 | top1 63.83% | top3 81.47% | top5 86.64% | 706.1 img/s | lr 3.15e-04 | gnorm 9.559 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.7359 | top1 62.04% | top3 79.75% | top5 85.24% | 712.8 img/s | lr 3.12e-04 | gnorm 8.393 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.7359 | top1 62.04% | top3 79.75% | top5 85.24% | lr 3.12e-04 | grad_norm 8.393 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5949 | top1 57.52% | top3 77.26% | top5 84.08%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 57.52%)
# Epoch time: 1.12 min
#
# === Epoch 46/100 ===
# [train step 400/704] loss 1.7028 | top1 63.52% | top3 81.21% | top5 86.60% | 717.4 img/s | lr 3.07e-04 | gnorm 13.144 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.7522 | top1 62.59% | top3 80.34% | top5 86.06% | 710.8 img/s | lr 3.04e-04 | gnorm 9.696 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.7522 | top1 62.59% | top3 80.34% | top5 86.06% | lr 3.04e-04 | grad_norm 9.696 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6135 | top1 57.24% | top3 77.04% | top5 84.10%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.12 min
#
# === Epoch 47/100 ===
# [train step 400/704] loss 1.6585 | top1 64.51% | top3 81.76% | top5 86.93% | 706.4 img/s | lr 2.99e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.7352 | top1 63.44% | top3 80.60% | top5 86.06% | 716.0 img/s | lr 2.96e-04 | gnorm inf | clip 100.0% | oflow 2 | nonfinite 0 | scale 128.0
# [Train] loss 1.7352 | top1 63.44% | top3 80.60% | top5 86.06% | lr 2.96e-04 | grad_norm inf | clip 100.0% | amp_overflows 2 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6538 | top1 57.76% | top3 76.70% | top5 83.88%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 57.76%)
# Epoch time: 1.12 min
#
# === Epoch 48/100 ===
# [train step 400/704] loss 1.6503 | top1 64.78% | top3 81.45% | top5 86.44% | 702.2 img/s | lr 2.91e-04 | gnorm 8.866 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.6891 | top1 64.22% | top3 81.10% | top5 86.31% | 699.6 img/s | lr 2.87e-04 | gnorm 8.764 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.6891 | top1 64.22% | top3 81.10% | top5 86.31% | lr 2.87e-04 | grad_norm 8.764 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6158 | top1 57.08% | top3 76.52% | top5 83.60%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.13 min
#
# === Epoch 49/100 ===
# [train step 400/704] loss 1.6391 | top1 64.70% | top3 81.23% | top5 86.38% | 701.2 img/s | lr 2.83e-04 | gnorm 8.486 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.6689 | top1 64.27% | top3 80.84% | top5 86.01% | 696.9 img/s | lr 2.79e-04 | gnorm 9.460 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.6689 | top1 64.27% | top3 80.84% | top5 86.01% | lr 2.79e-04 | grad_norm 9.460 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5763 | top1 57.32% | top3 77.90% | top5 84.84%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.14 min
#
# === Epoch 50/100 ===
# [train step 400/704] loss 1.5633 | top1 67.36% | top3 83.32% | top5 87.96% | 687.4 img/s | lr 2.75e-04 | gnorm 19.924 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.6298 | top1 65.69% | top3 81.89% | top5 86.70% | 696.5 img/s | lr 2.71e-04 | gnorm 13.776 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.6298 | top1 65.69% | top3 81.89% | top5 86.70% | lr 2.71e-04 | grad_norm 13.776 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6347 | top1 58.06% | top3 77.22% | top5 83.86%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 58.06%)
# Epoch time: 1.14 min
#
# === Epoch 51/100 ===
# [train step 400/704] loss 1.6334 | top1 65.56% | top3 81.82% | top5 86.83% | 729.5 img/s | lr 2.66e-04 | gnorm 6.007 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.6276 | top1 65.70% | top3 81.64% | top5 86.70% | 725.4 img/s | lr 2.63e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 128.0
# [Train] loss 1.6276 | top1 65.70% | top3 81.64% | top5 86.70% | lr 2.63e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5753 | top1 58.48% | top3 77.82% | top5 84.36%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 58.48%)
# Epoch time: 1.10 min
#
# === Epoch 52/100 ===
# [train step 400/704] loss 1.6480 | top1 66.73% | top3 82.67% | top5 87.51% | 718.5 img/s | lr 2.58e-04 | gnorm 7.662 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.6473 | top1 66.45% | top3 82.52% | top5 87.39% | 720.8 img/s | lr 2.55e-04 | gnorm 7.681 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.6473 | top1 66.45% | top3 82.52% | top5 87.39% | lr 2.55e-04 | grad_norm 7.681 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5486 | top1 59.80% | top3 78.26% | top5 84.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 59.80%)
# Epoch time: 1.11 min
#
# === Epoch 53/100 ===
# [train step 400/704] loss 1.5842 | top1 68.21% | top3 83.52% | top5 88.07% | 689.3 img/s | lr 2.50e-04 | gnorm 7.346 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.6000 | top1 67.01% | top3 82.55% | top5 87.21% | 691.5 img/s | lr 2.46e-04 | gnorm 11.644 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.6000 | top1 67.01% | top3 82.55% | top5 87.21% | lr 2.46e-04 | grad_norm 11.644 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5705 | top1 59.04% | top3 77.90% | top5 84.64%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.15 min
#
# === Epoch 54/100 ===
# [train step 400/704] loss 1.5968 | top1 67.12% | top3 81.98% | top5 86.69% | 703.8 img/s | lr 2.42e-04 | gnorm 12.050 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.5849 | top1 67.13% | top3 82.17% | top5 86.89% | 716.3 img/s | lr 2.38e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 64.0
# [Train] loss 1.5849 | top1 67.13% | top3 82.17% | top5 86.89% | lr 2.38e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 64.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5909 | top1 58.50% | top3 77.32% | top5 84.36%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 55/100 ===
# [train step 400/704] loss 1.4818 | top1 69.28% | top3 83.44% | top5 87.77% | 722.4 img/s | lr 2.33e-04 | gnorm 9.826 | clip 100.0% | oflow 0 | nonfinite 0 | scale 64.0
# [train step 704/704] loss 1.5184 | top1 69.08% | top3 83.48% | top5 87.92% | 715.4 img/s | lr 2.30e-04 | gnorm 8.874 | clip 100.0% | oflow 0 | nonfinite 0 | scale 64.0
# [Train] loss 1.5184 | top1 69.08% | top3 83.48% | top5 87.92% | lr 2.30e-04 | grad_norm 8.874 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 64.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5427 | top1 60.16% | top3 78.46% | top5 84.68%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Best saved to best_model_vit1.pt (val top1 60.16%)
# Epoch time: 1.12 min
#
# === Epoch 56/100 ===
# [train step 400/704] loss 1.5021 | top1 69.53% | top3 84.01% | top5 88.16% | 715.5 img/s | lr 2.25e-04 | gnorm 5.340 | clip 100.0% | oflow 0 | nonfinite 0 | scale 64.0
# [train step 704/704] loss 1.5115 | top1 69.25% | top3 83.93% | top5 88.30% | 721.5 img/s | lr 2.22e-04 | gnorm 13.580 | clip 100.0% | oflow 0 | nonfinite 0 | scale 64.0
# [Train] loss 1.5115 | top1 69.25% | top3 83.93% | top5 88.30% | lr 2.22e-04 | grad_norm 13.580 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 64.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5603 | top1 59.00% | top3 77.74% | top5 84.60%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.10 min
#
# === Epoch 57/100 ===
# [train step 400/704] loss 1.4696 | top1 69.71% | top3 83.59% | top5 88.04% | 715.2 img/s | lr 2.17e-04 | gnorm 5.827 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.5168 | top1 69.10% | top3 83.31% | top5 87.75% | 714.2 img/s | lr 2.14e-04 | gnorm 7.906 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.5168 | top1 69.10% | top3 83.31% | top5 87.75% | lr 2.14e-04 | grad_norm 7.906 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5319 | top1 59.50% | top3 78.44% | top5 85.02%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.11 min
#
# === Epoch 58/100 ===
# [train step 400/704] loss 1.4384 | top1 71.74% | top3 85.46% | top5 89.42% | 705.9 img/s | lr 2.09e-04 | gnorm 6.927 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.4665 | top1 70.97% | top3 84.91% | top5 89.07% | 699.1 img/s | lr 2.05e-04 | gnorm 7.244 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.4665 | top1 70.97% | top3 84.91% | top5 89.07% | lr 2.05e-04 | grad_norm 7.244 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5984 | top1 59.06% | top3 78.30% | top5 84.44%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.13 min
#
# === Epoch 59/100 ===
# [train step 400/704] loss 1.4005 | top1 72.04% | top3 85.20% | top5 89.00% | 720.1 img/s | lr 2.01e-04 | gnorm 7.847 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.4554 | top1 70.72% | top3 84.40% | top5 88.39% | 715.9 img/s | lr 1.97e-04 | gnorm 7.790 | clip 100.0% | oflow 0 | nonfinite 0 | scale 128.0
# [Train] loss 1.4554 | top1 70.72% | top3 84.40% | top5 88.39% | lr 1.97e-04 | grad_norm 7.790 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5505 | top1 59.42% | top3 78.38% | top5 85.22%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.11 min
#
# === Epoch 60/100 ===
# [train step 400/704] loss 1.3995 | top1 72.32% | top3 85.30% | top5 89.18% | 688.5 img/s | lr 1.93e-04 | gnorm 9.149 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.3916 | top1 72.29% | top3 85.47% | top5 89.35% | 690.6 img/s | lr 1.89e-04 | gnorm 7.546 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.3916 | top1 72.29% | top3 85.47% | top5 89.35% | lr 1.89e-04 | grad_norm 7.546 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.6116 | top1 58.74% | top3 77.22% | top5 83.74%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.15 min
#
# === Epoch 61/100 ===
# [train step 400/704] loss 1.3562 | top1 73.71% | top3 86.13% | top5 89.78% | 721.4 img/s | lr 1.85e-04 | gnorm 9.912 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.3629 | top1 73.52% | top3 86.14% | top5 89.82% | 716.3 img/s | lr 1.81e-04 | gnorm 8.088 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.3629 | top1 73.52% | top3 86.14% | top5 89.82% | lr 1.81e-04 | grad_norm 8.088 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5689 | top1 59.72% | top3 77.76% | top5 84.06%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.11 min
#
# === Epoch 62/100 ===
# [train step 400/704] loss 1.5039 | top1 71.35% | top3 84.56% | top5 88.61% | 688.6 img/s | lr 1.77e-04 | gnorm 8.867 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [train step 704/704] loss 1.4853 | top1 71.44% | top3 84.56% | top5 88.53% | 686.5 img/s | lr 1.73e-04 | gnorm 11.253 | clip 100.0% | oflow 0 | nonfinite 0 | scale 256.0
# [Train] loss 1.4853 | top1 71.44% | top3 84.56% | top5 88.53% | lr 1.73e-04 | grad_norm 11.253 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 256.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5621 | top1 60.16% | top3 78.40% | top5 84.24%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.15 min
#
# === Epoch 63/100 ===
# [train step 400/704] loss 1.4134 | top1 73.39% | top3 85.93% | top5 89.57% | 713.5 img/s | lr 1.69e-04 | gnorm 5.009 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [train step 704/704] loss 1.3714 | top1 73.84% | top3 86.48% | top5 90.01% | 709.9 img/s | lr 1.66e-04 | gnorm 6.644 | clip 100.0% | oflow 0 | nonfinite 0 | scale 512.0
# [Train] loss 1.3714 | top1 73.84% | top3 86.48% | top5 90.01% | lr 1.66e-04 | grad_norm 6.644 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 512.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5631 | top1 60.00% | top3 78.84% | top5 84.94%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Epoch time: 1.12 min
#
# === Epoch 64/100 ===
# [train step 400/704] loss 1.3467 | top1 74.00% | top3 86.30% | top5 89.74% | 721.0 img/s | lr 1.61e-04 | gnorm nan | clip 99.8% | oflow 2 | nonfinite 0 | scale 128.0
# [train step 704/704] loss 1.3625 | top1 73.67% | top3 86.07% | top5 89.64% | 719.5 img/s | lr 1.58e-04 | gnorm nan | clip 99.9% | oflow 2 | nonfinite 0 | scale 128.0
# [Train] loss 1.3625 | top1 73.67% | top3 86.07% | top5 89.64% | lr 1.58e-04 | grad_norm nan | clip 99.9% | amp_overflows 2 | nonfinite_loss 0 | scale 128.0
# [Train] mem_peak alloc 1.30 GiB | reserved 3.16 GiB
# [Val]   loss 1.5464 | top1 60.14% | top3 78.38% | top5 84.78%
# [Val]   mem_peak alloc 0.97 GiB | reserved 3.16 GiB
# Early-stop: no improvement on val_top1 for 9 epochs.

# %%
evaluate_one_epoch(model=model_v2_s, dataloader=test_loader)
# Out:
# (1.3429618577957154, {'top1': 64.66, 'top3': 82.78, 'top5': 88.05})

# %% [markdown]
# ---

# %%
avg_loss, metrics = evaluate_one_epoch(
    model=model_v2_s,
    dataloader=test_loader,
    device="cuda",
    use_amp=True,
    autocast_dtype="fp16",     
    channels_last=False,      
    measure_flops=True,       
    flops_warmup_batches=1)

print(f"loss: {avg_loss:.4f}")
print(f"top1: {metrics['top1']:.2f} | top3: {metrics['top3']:.2f} | top5: {metrics['top5']:.2f}")

print(f"throughput: {metrics['imgs_per_sec']:.1f} imgs/s | epoch: {metrics['epoch_time_sec']:.2f}s | ms/batch: {metrics['ms_per_batch']:.2f}")
print(f"GPU mem: alloc={metrics['gpu_mem_allocated_mib']:.0f} MiB | reserved={metrics['gpu_mem_reserved_mib']:.0f} MiB | peak={metrics['gpu_mem_peak_allocated_mib']:.0f} MiB")
print(f"model: params={int(metrics['model_params']):,} | param_size={metrics['model_param_size_mib']:.1f} MiB")

# FLOPs/MACs pueden salir nan si no tienes fvcore/thop instalado o si falla el profiler
print(f"FLOPs/forward: {metrics['flops_per_forward']:.3e} | MACs/forward: {metrics['macs_per_forward']:.3e}")
# Out:
# loss: 1.3438
# top1: 64.62 | top3: 82.81 | top5: 88.10
# throughput: 2099.3 imgs/s | epoch: 4.76s | ms/batch: 28.75
# GPU mem: alloc=956 MiB | reserved=3232 MiB | peak=1006 MiB
# model: params=20,305,588 | param_size=77.5 MiB
# FLOPs/forward: nan | MACs/forward: nan
