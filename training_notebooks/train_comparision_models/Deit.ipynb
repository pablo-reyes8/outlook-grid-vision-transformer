# %%
import sys, os

root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_path not in sys.path:
    sys.path.append(root_path)

# %%
from data.load_cifrar100 import *

train_loader, val_loader, test_loader = get_cifar100_dataloaders(
    batch_size=64,
    data_dir="./data",
    num_workers=2,
    val_split=0.1,
    img_size=32 , seed=7)

# %% [markdown]
# ## DeiT Transformer

# %% [markdown]
# ---

# %%
import torch.nn as nn
import timm
from src.training.train_full_model import * 
from src.training.metrics import * 
from src.training.eval_one_epoch_logs import *

device = 'cuda'

model_vit_small = timm.create_model(
    "deit_small_patch16_224",
    pretrained=False,
    num_classes=100,
    img_size=32,
    patch_size=4  
).to(device)

n_params = sum(p.numel() for p in model_vit_small.parameters() if p.requires_grad)
print(f"Trainable parameters: {n_params:,}")
# Out:
# Trainable parameters: 21,376,996

# %%
history, _ = train_model(
        model=model_vit_small,
        train_loader=train_loader,
        epochs=100,
        val_loader=val_loader,
        device=device,

        lr=5e-4,
        weight_decay=0.05,

        # Mixed Precision
        autocast_dtype="fp16" if device == "cuda" else "fp32",
        use_amp=(device == "cuda"),
        grad_clip_norm=1.0,

        warmup_ratio=0.05,
        min_lr=1e-6,

        label_smoothing=0.1,
        save_path= "best_model_resnet18.pt",
        last_path = "last_model_resnet18.pt",

        print_every=400,
        mix_prob=0.5,
        mixup_alpha=0.8,
        cutmix_alpha=1.0,

        num_classes=100,
        channels_last=True)
# Out:
# === Run config ===
# device=cuda | amp=True | autocast_dtype=fp16 | channels_last=True
# epochs=100 | steps/epoch=704 | total_steps=70400 | warmup_steps=3520
# batch_size=64 | input_shape=(64, 3, 32, 32) | num_classes=100
# opt=AdamW | lr=0.0005 | wd=0.05 | grad_clip_norm=1.0
# aug: mix_prob=0.5 | mixup_alpha=0.8 | cutmix_alpha=1.0 | label_smoothing=0.1
# ==================
#
# === Epoch 1/100 ===
# [train step 400/704] loss 4.4761 | top1 3.55% | top3 8.91% | top5 13.48% | 987.4 img/s | lr 5.68e-05 | gnorm 3.347 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 4.3685 | top1 4.72% | top3 11.56% | top5 17.14% | 984.3 img/s | lr 1.00e-04 | gnorm 3.317 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 4.3685 | top1 4.72% | top3 11.56% | top5 17.14% | lr 1.00e-04 | grad_norm 3.317 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 4.0149 | top1 8.48% | top3 20.10% | top5 27.34%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 8.48%)
# Epoch time: 0.81 min
#
# === Epoch 2/100 ===
# [train step 400/704] loss 4.1081 | top1 8.40% | top3 19.03% | top5 26.38% | 966.0 img/s | lr 1.57e-04 | gnorm 3.220 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 4.0650 | top1 8.91% | top3 19.97% | top5 27.55% | 963.3 img/s | lr 2.00e-04 | gnorm 3.230 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 4.0650 | top1 8.91% | top3 19.97% | top5 27.55% | lr 2.00e-04 | grad_norm 3.230 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.7861 | top1 12.20% | top3 25.68% | top5 34.56%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 12.20%)
# Epoch time: 0.83 min
#
# === Epoch 3/100 ===
# [train step 400/704] loss 3.9506 | top1 10.90% | top3 23.05% | top5 31.66% | 945.8 img/s | lr 2.57e-04 | gnorm 3.251 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.9296 | top1 11.05% | top3 23.79% | top5 32.39% | 941.7 img/s | lr 3.00e-04 | gnorm 3.267 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 3.9296 | top1 11.05% | top3 23.79% | top5 32.39% | lr 3.00e-04 | grad_norm 3.267 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.6403 | top1 14.16% | top3 28.42% | top5 38.36%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 14.16%)
# Epoch time: 0.85 min
#
# === Epoch 4/100 ===
# [train step 400/704] loss 3.8364 | top1 12.96% | top3 26.86% | top5 35.38% | 931.4 img/s | lr 3.57e-04 | gnorm 3.333 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 3.8150 | top1 13.07% | top3 27.11% | top5 35.86% | 929.6 img/s | lr 4.00e-04 | gnorm 3.382 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 3.8150 | top1 13.07% | top3 27.11% | top5 35.86% | lr 4.00e-04 | grad_norm 3.382 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.5464 | top1 15.50% | top3 31.02% | top5 41.12%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 15.50%)
# Epoch time: 0.86 min
#
# === Epoch 5/100 ===
# [train step 400/704] loss 3.7863 | top1 13.50% | top3 27.72% | top5 37.00% | 923.6 img/s | lr 4.57e-04 | gnorm 3.407 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 3.7726 | top1 13.81% | top3 28.17% | top5 37.44% | 922.7 img/s | lr 5.00e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.7726 | top1 13.81% | top3 28.17% | top5 37.44% | lr 5.00e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.5536 | top1 15.82% | top3 31.48% | top5 40.66%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 15.82%)
# Epoch time: 0.87 min
#
# === Epoch 6/100 ===
# [train step 400/704] loss 3.7473 | top1 14.13% | top3 29.12% | top5 38.47% | 919.8 img/s | lr 5.00e-04 | gnorm 3.530 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.7593 | top1 14.07% | top3 28.80% | top5 38.04% | 918.4 img/s | lr 5.00e-04 | gnorm 3.522 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.7593 | top1 14.07% | top3 28.80% | top5 38.04% | lr 5.00e-04 | grad_norm 3.522 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.5183 | top1 16.60% | top3 33.04% | top5 42.66%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 16.60%)
# Epoch time: 0.87 min
#
# === Epoch 7/100 ===
# [train step 400/704] loss 3.7000 | top1 15.21% | top3 30.63% | top5 39.99% | 915.2 img/s | lr 5.00e-04 | gnorm 3.436 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.7112 | top1 15.04% | top3 30.16% | top5 39.53% | 914.6 img/s | lr 4.99e-04 | gnorm 3.486 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.7112 | top1 15.04% | top3 30.16% | top5 39.53% | lr 4.99e-04 | grad_norm 3.486 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.4960 | top1 17.16% | top3 33.08% | top5 43.26%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 17.16%)
# Epoch time: 0.88 min
#
# === Epoch 8/100 ===
# [train step 400/704] loss 3.6609 | top1 16.11% | top3 31.61% | top5 41.05% | 911.8 img/s | lr 4.99e-04 | gnorm 3.522 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.6766 | top1 15.98% | top3 31.14% | top5 40.52% | 911.4 img/s | lr 4.99e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.6766 | top1 15.98% | top3 31.14% | top5 40.52% | lr 4.99e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.4261 | top1 17.62% | top3 35.76% | top5 45.62%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 17.62%)
# Epoch time: 0.88 min
#
# === Epoch 9/100 ===
# [train step 400/704] loss 3.6655 | top1 16.19% | top3 32.03% | top5 41.23% | 908.7 img/s | lr 4.98e-04 | gnorm 3.445 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.6692 | top1 16.24% | top3 31.75% | top5 41.23% | 909.0 img/s | lr 4.98e-04 | gnorm 3.387 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.6692 | top1 16.24% | top3 31.75% | top5 41.23% | lr 4.98e-04 | grad_norm 3.387 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.3779 | top1 19.24% | top3 35.62% | top5 46.02%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 19.24%)
# Epoch time: 0.88 min
#
# === Epoch 10/100 ===
# [train step 400/704] loss 3.6208 | top1 16.88% | top3 32.71% | top5 42.37% | 908.2 img/s | lr 4.97e-04 | gnorm 3.452 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.6134 | top1 17.00% | top3 32.80% | top5 42.33% | 908.9 img/s | lr 4.97e-04 | gnorm 3.429 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.6134 | top1 17.00% | top3 32.80% | top5 42.33% | lr 4.97e-04 | grad_norm 3.429 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.3054 | top1 19.66% | top3 38.34% | top5 48.54%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 19.66%)
# Epoch time: 0.88 min
#
# === Epoch 11/100 ===
# [train step 400/704] loss 3.5739 | top1 17.57% | top3 33.56% | top5 43.03% | 909.4 img/s | lr 4.96e-04 | gnorm 3.301 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.5484 | top1 18.28% | top3 34.54% | top5 43.94% | 909.3 img/s | lr 4.95e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.5484 | top1 18.28% | top3 34.54% | top5 43.94% | lr 4.95e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.2360 | top1 20.92% | top3 39.24% | top5 49.66%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 20.92%)
# Epoch time: 0.88 min
#
# === Epoch 12/100 ===
# [train step 400/704] loss 3.5487 | top1 18.50% | top3 34.77% | top5 44.74% | 912.3 img/s | lr 4.94e-04 | gnorm 3.339 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.5326 | top1 18.71% | top3 35.21% | top5 45.08% | 912.5 img/s | lr 4.93e-04 | gnorm 3.347 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.5326 | top1 18.71% | top3 35.21% | top5 45.08% | lr 4.93e-04 | grad_norm 3.347 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.2148 | top1 21.46% | top3 40.24% | top5 50.46%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 21.46%)
# Epoch time: 0.88 min
#
# === Epoch 13/100 ===
# [train step 400/704] loss 3.4868 | top1 19.40% | top3 36.47% | top5 45.83% | 912.8 img/s | lr 4.92e-04 | gnorm 3.369 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.4990 | top1 19.44% | top3 36.38% | top5 45.88% | 912.2 img/s | lr 4.91e-04 | gnorm 3.353 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.4990 | top1 19.44% | top3 36.38% | top5 45.88% | lr 4.91e-04 | grad_norm 3.353 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.1873 | top1 22.58% | top3 40.86% | top5 50.84%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 22.58%)
# Epoch time: 0.88 min
#
# === Epoch 14/100 ===
# [train step 400/704] loss 3.4540 | top1 20.14% | top3 37.38% | top5 47.21% | 909.8 img/s | lr 4.90e-04 | gnorm 3.301 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.4751 | top1 19.88% | top3 36.84% | top5 46.60% | 910.2 img/s | lr 4.89e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.4751 | top1 19.88% | top3 36.84% | top5 46.60% | lr 4.89e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.0989 | top1 24.00% | top3 42.74% | top5 52.98%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 24.00%)
# Epoch time: 0.88 min
#
# === Epoch 15/100 ===
# [train step 400/704] loss 3.4073 | top1 21.10% | top3 38.35% | top5 47.99% | 908.7 img/s | lr 4.88e-04 | gnorm 3.271 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.4225 | top1 20.96% | top3 38.23% | top5 47.95% | 908.5 img/s | lr 4.86e-04 | gnorm 3.247 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.4225 | top1 20.96% | top3 38.23% | top5 47.95% | lr 4.86e-04 | grad_norm 3.247 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.0774 | top1 24.30% | top3 44.12% | top5 53.44%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 24.30%)
# Epoch time: 0.88 min
#
# === Epoch 16/100 ===
# [train step 400/704] loss 3.4263 | top1 21.32% | top3 38.08% | top5 47.83% | 908.2 img/s | lr 4.85e-04 | gnorm 3.243 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.4209 | top1 21.18% | top3 38.42% | top5 48.22% | 907.8 img/s | lr 4.84e-04 | gnorm 3.204 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.4209 | top1 21.18% | top3 38.42% | top5 48.22% | lr 4.84e-04 | grad_norm 3.204 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 3.0675 | top1 25.12% | top3 43.68% | top5 54.50%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 25.12%)
# Epoch time: 0.88 min
#
# === Epoch 17/100 ===
# [train step 400/704] loss 3.3860 | top1 21.77% | top3 39.92% | top5 49.72% | 905.8 img/s | lr 4.82e-04 | gnorm 3.153 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.3526 | top1 22.10% | top3 40.26% | top5 50.06% | 906.1 img/s | lr 4.81e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.3526 | top1 22.10% | top3 40.26% | top5 50.06% | lr 4.81e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.9907 | top1 26.36% | top3 45.50% | top5 55.76%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 26.36%)
# Epoch time: 0.88 min
#
# === Epoch 18/100 ===
# [train step 400/704] loss 3.3209 | top1 23.09% | top3 41.37% | top5 51.16% | 907.8 img/s | lr 4.79e-04 | gnorm 3.214 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.3181 | top1 23.08% | top3 41.28% | top5 51.20% | 909.9 img/s | lr 4.77e-04 | gnorm 3.220 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.3181 | top1 23.08% | top3 41.28% | top5 51.20% | lr 4.77e-04 | grad_norm 3.220 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.9276 | top1 26.86% | top3 46.84% | top5 56.70%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 26.86%)
# Epoch time: 0.88 min
#
# === Epoch 19/100 ===
# [train step 400/704] loss 3.3044 | top1 23.59% | top3 41.53% | top5 51.53% | 912.1 img/s | lr 4.75e-04 | gnorm 3.254 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.2781 | top1 23.91% | top3 42.17% | top5 52.18% | 912.4 img/s | lr 4.74e-04 | gnorm 3.261 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.2781 | top1 23.91% | top3 42.17% | top5 52.18% | lr 4.74e-04 | grad_norm 3.261 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.9468 | top1 27.78% | top3 47.40% | top5 57.56%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 27.78%)
# Epoch time: 0.88 min
#
# === Epoch 20/100 ===
# [train step 400/704] loss 3.2235 | top1 25.25% | top3 43.73% | top5 53.44% | 911.9 img/s | lr 4.72e-04 | gnorm 3.253 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.2501 | top1 24.58% | top3 43.27% | top5 52.97% | 910.8 img/s | lr 4.70e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.2501 | top1 24.58% | top3 43.27% | top5 52.97% | lr 4.70e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.9101 | top1 28.64% | top3 47.74% | top5 57.66%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 28.64%)
# Epoch time: 0.88 min
#
# === Epoch 21/100 ===
# [train step 400/704] loss 3.2506 | top1 24.47% | top3 43.21% | top5 53.15% | 908.8 img/s | lr 4.68e-04 | gnorm 3.256 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.2427 | top1 24.58% | top3 43.36% | top5 53.21% | 909.5 img/s | lr 4.66e-04 | gnorm 3.212 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.2427 | top1 24.58% | top3 43.36% | top5 53.21% | lr 4.66e-04 | grad_norm 3.212 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.9051 | top1 28.06% | top3 48.28% | top5 58.30%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.87 min
#
# === Epoch 22/100 ===
# [train step 400/704] loss 3.2603 | top1 25.14% | top3 43.29% | top5 53.13% | 908.3 img/s | lr 4.63e-04 | gnorm 3.139 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.2395 | top1 25.34% | top3 43.88% | top5 53.63% | 908.2 img/s | lr 4.62e-04 | gnorm 3.182 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.2395 | top1 25.34% | top3 43.88% | top5 53.63% | lr 4.62e-04 | grad_norm 3.182 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.8920 | top1 28.46% | top3 48.38% | top5 59.50%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.87 min
#
# === Epoch 23/100 ===
# [train step 400/704] loss 3.1732 | top1 26.23% | top3 45.29% | top5 54.92% | 906.8 img/s | lr 4.59e-04 | gnorm 3.238 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.1941 | top1 25.92% | top3 44.61% | top5 54.31% | 905.9 img/s | lr 4.57e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 3.1941 | top1 25.92% | top3 44.61% | top5 54.31% | lr 4.57e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.8514 | top1 29.40% | top3 49.64% | top5 59.48%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 29.40%)
# Epoch time: 0.88 min
#
# === Epoch 24/100 ===
# [train step 400/704] loss 3.1413 | top1 27.19% | top3 46.04% | top5 55.39% | 906.0 img/s | lr 4.54e-04 | gnorm 3.184 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.1579 | top1 26.98% | top3 45.76% | top5 55.26% | 906.5 img/s | lr 4.52e-04 | gnorm 3.173 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.1579 | top1 26.98% | top3 45.76% | top5 55.26% | lr 4.52e-04 | grad_norm 3.173 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.8795 | top1 29.60% | top3 49.12% | top5 59.00%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 29.60%)
# Epoch time: 0.88 min
#
# === Epoch 25/100 ===
# [train step 400/704] loss 3.1039 | top1 27.62% | top3 46.76% | top5 56.74% | 909.6 img/s | lr 4.50e-04 | gnorm 3.149 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.1190 | top1 27.72% | top3 46.89% | top5 56.70% | 909.2 img/s | lr 4.47e-04 | gnorm 3.121 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 3.1190 | top1 27.72% | top3 46.89% | top5 56.70% | lr 4.47e-04 | grad_norm 3.121 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.7865 | top1 30.66% | top3 50.06% | top5 61.12%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 30.66%)
# Epoch time: 0.88 min
#
# === Epoch 26/100 ===
# [train step 400/704] loss 3.0703 | top1 28.50% | top3 48.08% | top5 57.87% | 909.7 img/s | lr 4.44e-04 | gnorm 3.171 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 3.1275 | top1 27.79% | top3 46.95% | top5 56.64% | 909.6 img/s | lr 4.42e-04 | gnorm 3.076 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 3.1275 | top1 27.79% | top3 46.95% | top5 56.64% | lr 4.42e-04 | grad_norm 3.076 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.7685 | top1 30.98% | top3 51.26% | top5 61.20%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 30.98%)
# Epoch time: 0.88 min
#
# === Epoch 27/100 ===
# [train step 400/704] loss 3.0601 | top1 29.39% | top3 49.22% | top5 58.84% | 906.5 img/s | lr 4.39e-04 | gnorm 3.124 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 3.0509 | top1 29.10% | top3 49.14% | top5 58.75% | 906.7 img/s | lr 4.37e-04 | gnorm 3.139 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 3.0509 | top1 29.10% | top3 49.14% | top5 58.75% | lr 4.37e-04 | grad_norm 3.139 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.6914 | top1 32.48% | top3 53.28% | top5 63.24%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 32.48%)
# Epoch time: 0.88 min
#
# === Epoch 28/100 ===
# [train step 400/704] loss 3.0272 | top1 30.16% | top3 49.69% | top5 59.82% | 907.2 img/s | lr 4.34e-04 | gnorm 3.006 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 3.0217 | top1 29.94% | top3 49.67% | top5 59.55% | 907.5 img/s | lr 4.31e-04 | gnorm 3.074 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 3.0217 | top1 29.94% | top3 49.67% | top5 59.55% | lr 4.31e-04 | grad_norm 3.074 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.6837 | top1 33.88% | top3 53.16% | top5 62.98%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 33.88%)
# Epoch time: 0.88 min
#
# === Epoch 29/100 ===
# [train step 400/704] loss 3.0771 | top1 29.51% | top3 48.90% | top5 58.61% | 907.2 img/s | lr 4.28e-04 | gnorm 2.938 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 3.0324 | top1 30.28% | top3 49.64% | top5 59.18% | 907.5 img/s | lr 4.25e-04 | gnorm inf | clip 100.0% | oflow 2 | nonfinite 0 | scale 65536.0
# [Train] loss 3.0324 | top1 30.28% | top3 49.64% | top5 59.18% | lr 4.25e-04 | grad_norm inf | clip 100.0% | amp_overflows 2 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.6945 | top1 33.84% | top3 53.18% | top5 63.04%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.87 min
#
# === Epoch 30/100 ===
# [train step 400/704] loss 2.9760 | top1 31.22% | top3 50.52% | top5 59.99% | 907.9 img/s | lr 4.22e-04 | gnorm 3.070 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.9581 | top1 31.14% | top3 50.90% | top5 60.46% | 907.9 img/s | lr 4.19e-04 | gnorm 3.108 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.9581 | top1 31.14% | top3 50.90% | top5 60.46% | lr 4.19e-04 | grad_norm 3.108 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.6481 | top1 33.52% | top3 54.22% | top5 63.78%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.87 min
#
# === Epoch 31/100 ===
# [train step 400/704] loss 2.9336 | top1 31.99% | top3 52.13% | top5 61.69% | 908.0 img/s | lr 4.16e-04 | gnorm 3.081 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.9332 | top1 31.97% | top3 51.94% | top5 61.52% | 908.6 img/s | lr 4.13e-04 | gnorm 3.073 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.9332 | top1 31.97% | top3 51.94% | top5 61.52% | lr 4.13e-04 | grad_norm 3.073 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.5710 | top1 35.02% | top3 56.32% | top5 66.30%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 35.02%)
# Epoch time: 0.88 min
#
# === Epoch 32/100 ===
# [train step 400/704] loss 2.8714 | top1 33.48% | top3 53.28% | top5 62.63% | 908.0 img/s | lr 4.10e-04 | gnorm 3.138 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.8781 | top1 33.30% | top3 53.37% | top5 62.71% | 907.3 img/s | lr 4.07e-04 | gnorm 3.115 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.8781 | top1 33.30% | top3 53.37% | top5 62.71% | lr 4.07e-04 | grad_norm 3.115 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.5682 | top1 35.92% | top3 56.34% | top5 65.76%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 35.92%)
# Epoch time: 0.88 min
#
# === Epoch 33/100 ===
# [train step 400/704] loss 2.8292 | top1 34.00% | top3 54.09% | top5 63.44% | 908.7 img/s | lr 4.03e-04 | gnorm 3.140 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.8250 | top1 34.19% | top3 54.52% | top5 63.96% | 907.3 img/s | lr 4.00e-04 | gnorm 3.134 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.8250 | top1 34.19% | top3 54.52% | top5 63.96% | lr 4.00e-04 | grad_norm 3.134 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.5106 | top1 36.56% | top3 57.12% | top5 66.48%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 36.56%)
# Epoch time: 0.88 min
#
# === Epoch 34/100 ===
# [train step 400/704] loss 2.8145 | top1 35.29% | top3 55.12% | top5 64.46% | 905.9 img/s | lr 3.97e-04 | gnorm 3.062 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.7948 | top1 35.23% | top3 55.24% | top5 64.65% | 906.8 img/s | lr 3.94e-04 | gnorm 3.097 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.7948 | top1 35.23% | top3 55.24% | top5 64.65% | lr 3.94e-04 | grad_norm 3.097 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.4983 | top1 36.60% | top3 57.08% | top5 67.14%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 36.60%)
# Epoch time: 0.88 min
#
# === Epoch 35/100 ===
# [train step 400/704] loss 2.7505 | top1 36.29% | top3 56.44% | top5 65.60% | 905.5 img/s | lr 3.90e-04 | gnorm 3.088 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.7773 | top1 35.80% | top3 55.95% | top5 65.28% | 905.1 img/s | lr 3.87e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 131072.0
# [Train] loss 2.7773 | top1 35.80% | top3 55.95% | top5 65.28% | lr 3.87e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.4515 | top1 37.74% | top3 58.80% | top5 68.20%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 37.74%)
# Epoch time: 0.88 min
#
# === Epoch 36/100 ===
# [train step 400/704] loss 2.6851 | top1 37.57% | top3 57.69% | top5 66.75% | 906.4 img/s | lr 3.83e-04 | gnorm 3.140 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.6839 | top1 37.30% | top3 57.74% | top5 66.75% | 904.9 img/s | lr 3.80e-04 | gnorm 3.135 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.6839 | top1 37.30% | top3 57.74% | top5 66.75% | lr 3.80e-04 | grad_norm 3.135 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.4459 | top1 38.98% | top3 58.56% | top5 68.32%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 38.98%)
# Epoch time: 0.89 min
#
# === Epoch 37/100 ===
# [train step 400/704] loss 2.7186 | top1 37.65% | top3 57.76% | top5 66.91% | 905.3 img/s | lr 3.76e-04 | gnorm 3.085 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.7486 | top1 37.31% | top3 57.31% | top5 66.41% | 904.4 img/s | lr 3.73e-04 | gnorm 3.028 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.7486 | top1 37.31% | top3 57.31% | top5 66.41% | lr 3.73e-04 | grad_norm 3.028 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.4386 | top1 38.24% | top3 59.32% | top5 68.32%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 38/100 ===
# [train step 400/704] loss 2.6432 | top1 39.31% | top3 59.76% | top5 68.52% | 903.2 img/s | lr 3.69e-04 | gnorm 3.109 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.6770 | top1 38.97% | top3 59.18% | top5 67.89% | 903.3 img/s | lr 3.66e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 131072.0
# [Train] loss 2.6770 | top1 38.97% | top3 59.18% | top5 67.89% | lr 3.66e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.3876 | top1 39.38% | top3 59.92% | top5 69.06%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 39.38%)
# Epoch time: 0.89 min
#
# === Epoch 39/100 ===
# [train step 400/704] loss 2.6061 | top1 40.09% | top3 60.16% | top5 69.00% | 903.9 img/s | lr 3.61e-04 | gnorm 3.086 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.6484 | top1 39.19% | top3 59.19% | top5 68.02% | 903.4 img/s | lr 3.58e-04 | gnorm 3.064 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.6484 | top1 39.19% | top3 59.19% | top5 68.02% | lr 3.58e-04 | grad_norm 3.064 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.3336 | top1 40.38% | top3 61.76% | top5 70.54%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 40.38%)
# Epoch time: 0.89 min
#
# === Epoch 40/100 ===
# [train step 400/704] loss 2.5944 | top1 40.27% | top3 60.64% | top5 69.23% | 904.2 img/s | lr 3.54e-04 | gnorm 3.078 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.6123 | top1 39.86% | top3 60.07% | top5 68.83% | 905.3 img/s | lr 3.51e-04 | gnorm 3.072 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.6123 | top1 39.86% | top3 60.07% | top5 68.83% | lr 3.51e-04 | grad_norm 3.072 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.3728 | top1 40.04% | top3 60.68% | top5 70.12%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 41/100 ===
# [train step 400/704] loss 2.5448 | top1 41.86% | top3 61.59% | top5 70.22% | 904.4 img/s | lr 3.46e-04 | gnorm 3.087 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.5510 | top1 41.73% | top3 61.84% | top5 70.41% | 905.9 img/s | lr 3.43e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 131072.0
# [Train] loss 2.5510 | top1 41.73% | top3 61.84% | top5 70.41% | lr 3.43e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.3335 | top1 39.96% | top3 61.68% | top5 71.04%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.87 min
#
# === Epoch 42/100 ===
# [train step 400/704] loss 2.4136 | top1 44.35% | top3 64.83% | top5 73.33% | 905.8 img/s | lr 3.39e-04 | gnorm 3.210 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.4504 | top1 43.44% | top3 64.16% | top5 72.72% | 906.3 img/s | lr 3.35e-04 | gnorm 3.195 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.4504 | top1 43.44% | top3 64.16% | top5 72.72% | lr 3.35e-04 | grad_norm 3.195 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.2551 | top1 42.60% | top3 63.30% | top5 72.00%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 42.60%)
# Epoch time: 0.88 min
#
# === Epoch 43/100 ===
# [train step 400/704] loss 2.4094 | top1 44.71% | top3 64.82% | top5 72.58% | 907.2 img/s | lr 3.31e-04 | gnorm 3.201 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.4523 | top1 44.03% | top3 64.03% | top5 71.97% | 907.2 img/s | lr 3.28e-04 | gnorm 3.165 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.4523 | top1 44.03% | top3 64.03% | top5 71.97% | lr 3.28e-04 | grad_norm 3.165 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.2620 | top1 42.28% | top3 63.72% | top5 73.44%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 44/100 ===
# [train step 400/704] loss 2.3878 | top1 45.29% | top3 65.40% | top5 73.70% | 907.2 img/s | lr 3.23e-04 | gnorm 3.218 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.3850 | top1 45.36% | top3 65.49% | top5 73.59% | 907.3 img/s | lr 3.20e-04 | gnorm inf | clip 100.0% | oflow 2 | nonfinite 0 | scale 65536.0
# [Train] loss 2.3850 | top1 45.36% | top3 65.49% | top5 73.59% | lr 3.20e-04 | grad_norm inf | clip 100.0% | amp_overflows 2 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.2216 | top1 43.58% | top3 63.90% | top5 73.24%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 43.58%)
# Epoch time: 0.88 min
#
# === Epoch 45/100 ===
# [train step 400/704] loss 2.3827 | top1 46.27% | top3 65.98% | top5 74.12% | 906.3 img/s | lr 3.15e-04 | gnorm 3.196 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.4239 | top1 45.27% | top3 64.91% | top5 73.13% | 906.6 img/s | lr 3.12e-04 | gnorm 3.190 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.4239 | top1 45.27% | top3 64.91% | top5 73.13% | lr 3.12e-04 | grad_norm 3.190 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.2846 | top1 41.70% | top3 63.02% | top5 71.86%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.87 min
#
# === Epoch 46/100 ===
# [train step 400/704] loss 2.3451 | top1 47.14% | top3 66.96% | top5 74.80% | 904.1 img/s | lr 3.07e-04 | gnorm 3.275 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.3347 | top1 47.18% | top3 67.08% | top5 74.92% | 903.6 img/s | lr 3.04e-04 | gnorm 3.277 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.3347 | top1 47.18% | top3 67.08% | top5 74.92% | lr 3.04e-04 | grad_norm 3.277 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.2221 | top1 43.20% | top3 64.46% | top5 73.36%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 47/100 ===
# [train step 400/704] loss 2.2811 | top1 49.52% | top3 68.91% | top5 76.26% | 903.7 img/s | lr 2.99e-04 | gnorm 3.281 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.2754 | top1 49.38% | top3 68.98% | top5 76.47% | 903.1 img/s | lr 2.96e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 2.2754 | top1 49.38% | top3 68.98% | top5 76.47% | lr 2.96e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1479 | top1 45.28% | top3 66.20% | top5 75.24%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 45.28%)
# Epoch time: 0.88 min
#
# === Epoch 48/100 ===
# [train step 400/704] loss 2.1801 | top1 50.92% | top3 70.34% | top5 77.75% | 902.0 img/s | lr 2.91e-04 | gnorm 3.388 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.2231 | top1 49.89% | top3 69.44% | top5 76.76% | 902.0 img/s | lr 2.87e-04 | gnorm 3.358 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.2231 | top1 49.89% | top3 69.44% | top5 76.76% | lr 2.87e-04 | grad_norm 3.358 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.2119 | top1 44.58% | top3 64.22% | top5 72.92%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 49/100 ===
# [train step 400/704] loss 2.1722 | top1 51.29% | top3 70.43% | top5 77.85% | 901.6 img/s | lr 2.83e-04 | gnorm 3.393 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.1851 | top1 51.10% | top3 70.41% | top5 77.72% | 901.5 img/s | lr 2.79e-04 | gnorm 3.393 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.1851 | top1 51.10% | top3 70.41% | top5 77.72% | lr 2.79e-04 | grad_norm 3.393 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1729 | top1 45.16% | top3 65.80% | top5 74.14%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 50/100 ===
# [train step 400/704] loss 2.1759 | top1 52.03% | top3 70.86% | top5 77.68% | 901.9 img/s | lr 2.75e-04 | gnorm 3.371 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.1426 | top1 52.46% | top3 71.38% | top5 78.24% | 901.8 img/s | lr 2.71e-04 | gnorm 3.413 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.1426 | top1 52.46% | top3 71.38% | top5 78.24% | lr 2.71e-04 | grad_norm 3.413 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1127 | top1 46.20% | top3 67.64% | top5 75.56%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 46.20%)
# Epoch time: 0.89 min
#
# === Epoch 51/100 ===
# [train step 400/704] loss 2.0881 | top1 53.62% | top3 72.07% | top5 78.89% | 901.5 img/s | lr 2.66e-04 | gnorm 3.428 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.1332 | top1 52.77% | top3 71.38% | top5 78.26% | 901.1 img/s | lr 2.63e-04 | gnorm 3.421 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 2.1332 | top1 52.77% | top3 71.38% | top5 78.26% | lr 2.63e-04 | grad_norm 3.421 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1423 | top1 45.36% | top3 66.30% | top5 75.20%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 52/100 ===
# [train step 400/704] loss 2.0465 | top1 55.30% | top3 73.93% | top5 80.49% | 900.4 img/s | lr 2.58e-04 | gnorm 3.514 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 2.0850 | top1 54.60% | top3 73.38% | top5 79.95% | 901.7 img/s | lr 2.55e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 2.0850 | top1 54.60% | top3 73.38% | top5 79.95% | lr 2.55e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1421 | top1 45.76% | top3 66.42% | top5 74.44%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 53/100 ===
# [train step 400/704] loss 2.0378 | top1 55.54% | top3 73.77% | top5 80.64% | 900.5 img/s | lr 2.50e-04 | gnorm 3.490 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.0443 | top1 55.13% | top3 73.41% | top5 80.12% | 900.4 img/s | lr 2.46e-04 | gnorm 3.500 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.0443 | top1 55.13% | top3 73.41% | top5 80.12% | lr 2.46e-04 | grad_norm 3.500 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1247 | top1 46.42% | top3 67.10% | top5 75.08%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 46.42%)
# Epoch time: 0.89 min
#
# === Epoch 54/100 ===
# [train step 400/704] loss 2.0228 | top1 56.96% | top3 74.80% | top5 80.94% | 901.2 img/s | lr 2.42e-04 | gnorm 3.499 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 2.0268 | top1 56.76% | top3 74.57% | top5 80.82% | 900.9 img/s | lr 2.38e-04 | gnorm 3.509 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 2.0268 | top1 56.76% | top3 74.57% | top5 80.82% | lr 2.38e-04 | grad_norm 3.509 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0888 | top1 47.94% | top3 67.66% | top5 76.34%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 47.94%)
# Epoch time: 0.89 min
#
# === Epoch 55/100 ===
# [train step 400/704] loss 1.8888 | top1 59.54% | top3 76.80% | top5 82.80% | 901.0 img/s | lr 2.33e-04 | gnorm 3.574 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.9652 | top1 57.91% | top3 75.34% | top5 81.61% | 901.3 img/s | lr 2.30e-04 | gnorm 3.562 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 1.9652 | top1 57.91% | top3 75.34% | top5 81.61% | lr 2.30e-04 | grad_norm 3.562 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0995 | top1 48.00% | top3 67.88% | top5 75.96%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 48.00%)
# Epoch time: 0.89 min
#
# === Epoch 56/100 ===
# [train step 400/704] loss 1.9024 | top1 59.41% | top3 76.52% | top5 82.16% | 900.0 img/s | lr 2.25e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.9117 | top1 59.14% | top3 76.27% | top5 82.00% | 900.6 img/s | lr 2.22e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss
| clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0368 | top1 49.60% | top3 69.22% | top5 77.30%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 64/100 ===
# [train step 400/704] loss 1.6574 | top1 66.85% | top3 80.84% | top5 85.57% | 901.7 img/s | lr 1.61e-04 | gnorm 3.780 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.6945 | top1 66.15% | top3 80.45% | top5 85.29% | 902.6 img/s | lr 1.58e-04 | gnorm 3.751 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# ...
# [train step 400/704] loss 1.4338 | top1 71.86% | top3 83.73% | top5 87.40% | 900.7 img/s | lr 1.17e-04 | gnorm 3.750 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.5007 | top1 70.86% | top3 83.10% | top5 86.90% | 901.1 img/s | lr 1.14e-04 | gnorm 3.769 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 1.5007 | top1 70.86% | top3 83.10% | top5 86.90% | lr 1.14e-04 | grad_norm 3.769 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 1.9907 | top1 51.02% | top3 70.90% | top5 78.12%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 71/100 ===
# [train step 400/704] loss 1.5372 | top1 70.28% | top3 82.00% | top5 86.01% | 903.6 img/s | lr 1.10e-04 | gnorm 3.727 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 1.5609 | top1 70.06% | top3 82.16% | top5 86.19% | 903.9 img/s | lr 1.07e-04 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 1.5609 | top1 70.06% | top3 82.16% | top5 86.19% | lr 1.07e-04 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0338 | top1 50.18% | top3 69.90% | top5 77.50%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 72/100 ===
# [train step 400/704] loss 1.5006 | top1 71.56% | top3 83.35% | top5 87.11% | 902.9 img/s | lr 1.03e-04 | gnorm 3.646 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.4691 | top1 72.04% | top3 83.73% | top5 87.52% | 903.3 img/s | lr 1.01e-04 | gnorm 3.704 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 1.4691 | top1 72.04% | top3 83.73% | top5 87.52% | lr 1.01e-04 | grad_norm 3.704 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.1187 | top1 50.30% | top3 69.70% | top5 77.92%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 73/100 ===
# [train step 400/704] loss 1.5894 | top1 71.01% | top3 82.72% | top5 86.72% | 901.7 img/s | lr 9.68e-05 | gnorm 3.601 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.5314 | top1 71.70% | top3 83.30% | top5 87.18% | 901.6 img/s | lr 9.40e-05 | gnorm 3.663 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 1.5314 | top1 71.70% | top3 83.30% | top5 87.18% | lr 9.40e-05 | grad_norm 3.663 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0280 | top1 51.30% | top3 70.42% | top5 77.70%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 51.30%)
# Epoch time: 0.89 min
#
# === Epoch 74/100 ===
# [train step 400/704] loss 1.4861 | top1 73.03% | top3 84.09% | top5 87.86% | 900.5 img/s | lr 9.04e-05 | gnorm 3.670 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.5086 | top1 72.76% | top3 83.96% | top5 87.74% | 901.3 img/s | lr 8.77e-05 | gnorm 3.678 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [Train] loss 1.5086 | top1 72.76% | top3 83.96% | top5 87.74% | lr 8.77e-05 | grad_norm 3.678 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 131072.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0293 | top1 51.60% | top3 70.82% | top5 78.12%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 51.60%)
# Epoch time: 0.89 min
#
# === Epoch 75/100 ===
# [train step 400/704] loss 1.5278 | top1 71.53% | top3 82.29% | top5 86.05% | 900.3 img/s | lr 8.42e-05 | gnorm 3.624 | clip 100.0% | oflow 0 | nonfinite 0 | scale 131072.0
# [train step 704/704] loss 1.5062 | top1 72.28% | top3 83.17% | top5 86.92% | 901.1 img/s | lr 8.15e-05 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 1.5062 | top1 72.28% | top3 83.17% | top5 86.92% | lr 8.15e-05 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 1.9998 | top1 51.96% | top3 70.56% | top5 77.94%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Best saved to best_model_resnet18.pt (val top1 51.96%)
# Epoch time: 0.89 min
#
# === Epoch 76/100 ===
# [train step 400/704] loss 1.5106 | top1 71.88% | top3 82.87% | top5 86.50% | 901.6 img/s | lr 7.81e-05 | gnorm 3.599 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1
| gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.2554 | top1 78.66% | top3 87.43% | top5 90.31% | 900.9 img/s | lr 1.73e-05 | gnorm inf | clip 100.0% | oflow 1 | nonfinite 0 | scale 65536.0
# [Train] loss 1.2554 | top1 78.66% | top3 87.43% | top5 90.31% | lr 1.73e-05 | grad_norm inf | clip 100.0% | amp_overflows 1 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0586 | top1 52.98% | top3 71.12% | top5 78.04%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 90/100 ===
# [train step 400/704] loss 1.2903 | top1 77.87% | top3 86.82% | top5 89.88% | 900.5 img/s | lr 1.57e-05 | gnorm 3.549 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.3192 | top1 77.26% | top3 86.38% | top5 89.50% | 900.9 img/s | lr 1.45e-05 | gnorm 3.577 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 1.3192 | top1 77.26% | top3 86.38% | top5 89.50% | lr 1.45e-05 | grad_norm 3.577 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 1.9926 | top1 53.16% | top3 71.26% | top5 78.28%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Epoch time: 0.88 min
#
# === Epoch 91/100 ===
# [train step 400/704] loss 1.3496 | top1 77.11% | top3 86.34% | top5 89.44% | 901.3 img/s | lr 1.30e-05 | gnorm 3.500 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [train step 704/704] loss 1.3975 | top1 76.20% | top3 85.52% | top5 88.74% | 901.1 img/s | lr 1.20e-05 | gnorm 3.529 | clip 100.0% | oflow 0 | nonfinite 0 | scale 65536.0
# [Train] loss 1.3975 | top1 76.20% | top3 85.52% | top5 88.74% | lr 1.20e-05 | grad_norm 3.529 | clip 100.0% | amp_overflows 0 | nonfinite_loss 0 | scale 65536.0
# [Train] mem_peak alloc 1.72 GiB | reserved 2.47 GiB
# [Val]   loss 2.0070 | top1 53.06% | top3 72.36% | top5 78.66%
# [Val]   mem_peak alloc 1.16 GiB | reserved 2.47 GiB
# Early-stop: no improvement on val_top1 for 9 epochs.

# %% [markdown]
# ---

# %%
avg_loss, metrics = evaluate_one_epoch(
    model=model_vit_small,
    dataloader=test_loader,
    device="cuda",
    use_amp=True,
    autocast_dtype="fp16",     
    channels_last=False,      
    measure_flops=True,       
    flops_warmup_batches=1)

print(f"loss: {avg_loss:.4f}")
print(f"top1: {metrics['top1']:.2f} | top3: {metrics['top3']:.2f} | top5: {metrics['top5']:.2f}")

print(f"throughput: {metrics['imgs_per_sec']:.1f} imgs/s | epoch: {metrics['epoch_time_sec']:.2f}s | ms/batch: {metrics['ms_per_batch']:.2f}")
print(f"GPU mem: alloc={metrics['gpu_mem_allocated_mib']:.0f} MiB | reserved={metrics['gpu_mem_reserved_mib']:.0f} MiB | peak={metrics['gpu_mem_peak_allocated_mib']:.0f} MiB")
print(f"model: params={int(metrics['model_params']):,} | param_size={metrics['model_param_size_mib']:.1f} MiB")

# FLOPs/MACs pueden salir nan si no tienes fvcore/thop instalado o si falla el profiler
print(f"FLOPs/forward: {metrics['flops_per_forward']:.3e} | MACs/forward: {metrics['macs_per_forward']:.3e}")
# Out:
# loss: 1.6656
# top1: 59.00 | top3: 76.31 | top5: 82.59
# throughput: 3432.9 imgs/s | epoch: 2.91s | ms/batch: 17.68
# GPU mem: alloc=1094 MiB | reserved=2526 MiB | peak=1187 MiB
# model: params=21,376,996 | param_size=81.5 MiB
# FLOPs/forward: nan | MACs/forward: nan
